# %%
import json
import pandas as pd
import numpy as np
import glob
import os
from courier_cleaning import *

pd.set_option('display.max_columns', 1000)

# %% [markdown]
# # Read in session.jsonl file

# %%
def add_keypress(events, rec_type, rec_stop_type):
    rec_evs = events.query('type == @rec_type | type == @rec_stop_type')
    rec_evs_index = rec_evs.index
    
    for i in range(len(rec_evs)-1):
        
        curr_row = rec_evs.iloc[i]
        if curr_row.type != rec_type:
            continue
        next_row = rec_evs.iloc[i+1]

        curr_time = curr_row.mstime
        next_time = next_row.mstime

        EFR_candidates = events.query('type == "keypress" & \
                                       mstime > @curr_time & mstime < @next_time')
        if len(EFR_candidates) > 0:
            response_time = EFR_candidates.mstime.values[0]

            events.at[rec_evs_index[i], "keypress"] = True
            events.at[rec_evs_index[i], "keypress_mstime"] = response_time
        
        # if no correct key press happened, check for additional key presses
        else:
            next_candidates = events.query('type == "key press/release" & \
                                            mstime > @curr_time & mstime < @next_time')
            display(next_candidates)
            if len(next_candidates) > 0:
                responses = next_candidates["key code"].unique()
                responses = responses[~np.isnan(responses)]
                print(responses)
                response_time = next_candidates.mstime.values[0]
                
                events.at[rec_evs_index[i], "keypress_keycode"] = responses.tolist()
                events.at[rec_evs_index[i], "keypress_mstime"] = response_time
    
    return events

# %%
with open('/scratch/new_courier_pilot/dbpool.txt', "r") as f:
    wordpool = [w.strip().upper() for w in f.readlines()]

data_dir = "/scratch/new_courier_pilot/"
sub_dirs = []

# get subject level directory info
for root, dirs, files in os.walk(data_dir):
    for name in files:
        if name.endswith("session.jsonl"):
            sub_dirs.append(root)
            
print(sub_dirs)


for sub_dir in sub_dirs:
    _, _, _, sub, sess_txt = sub_dir.split("/")
    sess = int(sess_txt[-1])
    print("subject {}, sess {}".format(sub, sess))
    
    # check if the data is already saved in data_dir
    file_name = "{}_sess_{}.csv".format(sub, sess)
    file_dir = os.path.join(data_dir, file_name)
#     if os.path.exists(file_dir):
#         print("already saved")
#         continue
    
    break
    
    sub_data = []
    # locate session.jsonl
    sess_dir = os.path.join(data_dir, sub_dir, "session.jsonl")
    for line in open(sess_dir, "r"):
        # replace this specific entry to empty string
        if '"point condition":SerialPosition,' in line:
            line = line.replace('"point condition":SerialPosition,', '')
        elif '"point condition":SpatialPosition,' in line:
            line = line.replace('"point condition":SpatialPosition,', '')
        elif '"point condition":Random,' in line:
            line = line.replace('"point condition":Random,', '')
            
        data_dict = json.loads(line)
        sub_data.append(data_dict)
    
    # create dataframe
    for d in sub_data:
        for k,v in d["data"].items():
            d[k] = v
    df = pd.DataFrame(sub_data)
        
    column_names = ["type", "time", "trial number", "item name", "item", "serial position", "store", "store name", "store position", 
                "player position", "positionX", "positionZ", "correct direction (degrees)", "pointed direction (degrees)", "response", "key code"]
    df = df[column_names]
    df = df.rename(columns={
                            'trial number': 'trial',
                            'time': 'mstime',
                            'serial position': 'serialpos',
                            'item': 'cued_item',
                            'store': 'cued_store',
                            'store name': 'store',
                            'item name': 'item'
                            })
    df["subject"] = sub
    df["session"] = sess
    df["recalled"] = -999
    df["intrusion"] = -999

    # change the type name to match lab's data frame formatting
    df = df.replace({'type': {'object presentation begins': 'WORD', 
                                  'free recall': 'REC_WORD',
                                  'object recall recording start': 'REC_START',
                                  'object recall recording stop': 'REC_STOP',
                                  'cued recall recording stop': 'CUED_REC_STOP',
                                  'cued recall': 'CUED_REC_WORD',
                                  'final store recall': 'FSR_REC_WORD',
                                  'final store recall recording stop': 'FSR_REC_STOP',
                                  'final object recall': 'FFR_REC_WORD',
                                  'final object recall recording stop': 'FFR_REC_STOP'
                                 }
                        })
    
    ###############################################################################################
    # FREE RECALL
    ###############################################################################################
    recall_df = pd.DataFrame(columns = df.columns)
    rec_starts = df.query('type == "REC_START"')
    # first REC_START will indicate practice recall stage for session 0
    if sess == 0:
        rec_starts = rec_starts[1:]
        
    count = 0
    for i, row in rec_starts.iterrows():
        rec_start_time = row.mstime

        # let's load appropriate .ann files
        annotation_file = "{}.ann".format(count)
        annotation_dir = os.path.join(data_dir, sub_dir, annotation_file)
        with open(annotation_dir, "r") as file:
            lines = file.readlines()
            for line in lines:
                if line[0] != "#":
                    recall_info = line.strip("\n").split("\t")

                    if len(recall_info) == 3:
                        rectime = float(recall_info[0]) + rec_start_time
                        item = recall_info[2].lower()
                        itemno = recall_info[1]

                        recall_df = recall_df.append({"subject":sub,
                                                      "session":sess,
                                                      "type":"REC_WORD", 
                                                      "mstime":rectime, 
                                                      "trial":count, 
                                                      "item":item, 
                                                      "itemno":itemno
                                                     }, ignore_index=True)
        count += 1

    # then, fill out the blanks
    recall_df["store"] = recall_df["store"].astype(str)
    recall_df["store position"] = recall_df["store position"].astype(str)

    for i, row in recall_df.iterrows():
        word_evs = df[(df.trial == row.trial) & (df.type == "WORD")]

        row_item = row["item"]
        recall_word = word_evs.query('item == @row_item')

        if len(recall_word) != 0:        
            serialpos = recall_word["serialpos"].values[0]
            store = recall_word["store"].values[0]
            store_position = recall_word["store position"].values[0]

            recall_df.at[i, "serialpos"] = serialpos
            recall_df.at[i, "store"] = store
            recall_df.at[i, "store position"] = store_position

        else:
            recall_df.at[i, "serialpos"] = -999
    
    ###############################################################################################
    # CUED RECALL
    ###############################################################################################
    cued_rec_start = df.query('type == "start cued recall"').mstime.values
    if sess == 0:
        cued_rec_start = cued_rec_start[1]
    else:
        cued_rec_start = cued_rec_start[0]
    
    cued_rec_events = df.query('type == "cued recall recording start" & mstime >= @cued_rec_start')
    cued_recall_df = pd.DataFrame(columns = df.columns)

    for i, row in cued_rec_events.iterrows():
        trial = int(row.trial)
        cued_item = row.cued_item
        cued_store = row.cued_store
        cued_time = row.mstime

        word_evs = df.query('type == "WORD" & subject == @sub & trial == @trial')
        stores = word_evs.store.unique()

        if cued_store not in stores:
            continue

        # locate the .ann file
        annotation_file = "{}-{}.ann".format(trial, cued_store)
        annotation_dir = os.path.join(data_dir, sub_dir, annotation_file)
        with open(annotation_dir, "r") as file:
            lines = file.readlines()
            for line in lines:
                if line[0] != "#":
                    recall_info = line.strip("\n").split("\t")

                    if len(recall_info) == 3:
                        rectime = float(recall_info[0]) + cued_time
                        item = recall_info[2].lower()
                        itemno = recall_info[1]

                        cued_recall_df = cued_recall_df.append({"subject":sub,
                                                                "session":sess,
                                                                "type": "CUED_REC_WORD", 
                                                                "mstime": rectime, 
                                                                "trial": trial, 
                                                                "item": item, 
                                                                "itemno": itemno, 
                                                                "cued_item": cued_item, 
                                                                "cued_store": cued_store 
                                                                }, ignore_index=True)
                        
    # then, fill out the blanks
    cued_recall_df["store"] = cued_recall_df["store"].astype(str)
    cued_recall_df["store position"] = cued_recall_df["store position"].astype(str)

    for i, row in cued_recall_df.iterrows():
        word_evs = df[(df.trial == row.trial) & (df.type == "WORD")]

        row_item = row["item"]
        recall_word = word_evs.query('item == @row_item')

        if len(recall_word) != 0:        
            serialpos = recall_word["serialpos"].values[0]
            store = recall_word["store"].values[0]
            store_position = recall_word["store position"].values[0]

            cued_recall_df.at[i, "serialpos"] = serialpos
            cued_recall_df.at[i, "store"] = store
            cued_recall_df.at[i, "store position"] = store_position

        else:
            cued_recall_df.at[i, "serialpos"] = -999
            
    ###############################################################################################
    # FINAL STORE RECALL
    ###############################################################################################
    FFR_store_df = pd.DataFrame(columns = df.columns)
    FFR_store_evs = df.query('type == "final store recall recording start"')
    if len(FFR_store_evs) != 0:
        FFR_store_start = FFR_store_evs.mstime.values[0]
    
        # let's load appropriate .ann files
        annotation_dir = os.path.join(data_dir, sub_dir, "final store-0.ann")
        with open(annotation_dir, "r") as file:
            lines = file.readlines()
            for line in lines:
                if line[0] != "#":
                    recall_info = line.strip("\n").split("\t")

                    if len(recall_info) == 3:
                        rectime = float(recall_info[0]) + FFR_store_start
                        item = recall_info[2].lower()
                        itemno = recall_info[1]

                        FFR_store_df = FFR_store_df.append({"subject":sub,
                                                            "session":sess,
                                                            "type":"FFR_STORE", 
                                                            "mstime":rectime, 
                                                            "item":item, 
                                                            "itemno":itemno, 
                                                           }, ignore_index=True)
    
    ###############################################################################################
    # FINAL ITEM RECALL
    ###############################################################################################
    FFR_item_df = pd.DataFrame(columns = df.columns)
    FFR_item_evs = df.query('type == "final object recall recording start"')
    if len(FFR_item_evs) != 0:
        FFR_item_start = FFR_item_evs.mstime.values[0]

        # let's load appropriate .ann files
        annotation_dir = os.path.join(data_dir, sub_dir, "final free-0.ann")
        with open(annotation_dir, "r") as file:
            lines = file.readlines()
            for line in lines:
                if line[0] != "#":
                    recall_info = line.strip("\n").split("\t")

                    if len(recall_info) == 3:
                        rectime = float(recall_info[0]) + FFR_item_start
                        item = recall_info[2].lower()
                        itemno = recall_info[1]

                        FFR_item_df = FFR_item_df.append({"subject":sub,
                                                          "session":sess,
                                                          "type":"FFR_ITEM", 
                                                          "mstime":rectime, 
                                                          "item":item, 
                                                          "itemno":itemno
                                                         }, ignore_index=True)

        # then, fill out the blanks
        FFR_item_df["store"] = FFR_item_df["store"].astype(str)
        FFR_item_df["store position"] = FFR_item_df["store position"].astype(str)

        for i, row in FFR_item_df.iterrows():
            word_evs = df.query('type == "WORD"')

            row_item = row["item"]
            recall_word = word_evs.query('item == @row_item')

            if len(recall_word) != 0:        
                serialpos = recall_word["serialpos"].values[0]
                store = recall_word["store"].values[0]
                store_position = recall_word["store position"].values[0]

                FFR_item_df.at[i, "serialpos"] = serialpos
                FFR_item_df.at[i, "store"] = store
                FFR_item_df.at[i, "store position"] = store_position

            else:
                FFR_item_df.at[i, "serialpos"] = -999
            
    ###############################################################################################
    # ARRANGE
    ###############################################################################################
    # now put it in right place
    tmp = df.copy()
    tmp = tmp.append(recall_df)
    tmp = tmp.append(cued_recall_df)
    tmp = tmp.append(FFR_store_df)
    tmp = tmp.append(FFR_item_df)
    tmp = tmp.sort_values('mstime').reset_index(drop=True)
    
    tmp[["trial", "serialpos", "recalled", "itemno", "intrusion"]] = tmp[["trial", "serialpos", "recalled", "itemno", "intrusion"]].fillna(-999)
    tmp = tmp.astype({"trial":int, "serialpos":int, "recalled":int, "itemno":int, "intrusion":int})
    
    tmp = add_recalled(tmp)
    tmp = add_itemno(tmp, wordpool)
    tmp = add_intrusion(tmp)
    
    ###############################################################################################
    # add EFR presses
    ###############################################################################################
    tmp["keypress_code"] = np.nan
    tmp = tmp.astype({"keypress_code":object})
    
    tmp = add_keypress(tmp, "REC_WORD", "REC_STOP")
    tmp = add_keypress(tmp, "CUED_REC_WORD", "CUED_REC_STOP")
    tmp = add_keypress(tmp, "FSR_REC_WORD", "FSR_REC_STOP")
    tmp = add_keypress(tmp, "FFR_REC_WORD", "FFR_REC_STOP")
# Out:
# ['/scratch/new_courier_pilot/', '/scratch/new_courier_pilot/PILOT1/session_0', '/scratch/new_courier_pilot/PILOT2/session_0', '/scratch/new_courier_pilot/PILOT3/session_0', '/scratch/new_courier_pilot/PILOT4/session_1', '/scratch/new_courier_pilot/PILOT4/session_0', '/scratch/new_courier_pilot/PILOT5/session_1', '/scratch/new_courier_pilot/PILOT5/session_0', '/scratch/new_courier_pilot/PILOT6/session_1', '/scratch/new_courier_pilot/PILOT6/session_0']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-3758826ea0cf> in <module>
#      15
#      16 for sub_dir in sub_dirs:
# ---> 17     _, _, _, sub, sess_txt = sub_dir.split("/")
#      18     sess = int(sess_txt[-1])
#      19     print("subject {}, sess {}".format(sub, sess))
#
# ValueError: not enough values to unpack (expected 5, got 4)

# %%
a = tmp.query('type == "CUED_REC_WORD"')
a
# Out:
#                 type        mstime  trial          item          cued_item  \
# 11955  CUED_REC_WORD  1.652297e+12      0        decals             decals
# 12025  CUED_REC_WORD  1.652297e+12      0      pastries           pastries
# 12092  CUED_REC_WORD  1.652297e+12      0     anchovies          anchovies
# 12197  CUED_REC_WORD  1.652297e+12      0            <>              watch
# 12225  CUED_REC_WORD  1.652297e+12      0    guinea_pig         guinea_pig
# 12289  CUED_REC_WORD  1.652297e+12      0     floor_mat          floor_mat
# 12371  CUED_REC_WORD  1.652297e+12      0       markers            markers
# 12475  CUED_REC_WORD  1.652297e+12      0            <>             towels
# 12543  CUED_REC_WORD  1.652297e+12      0            <>            syringe
# 12576  CUED_REC_WORD  1.652297e+12      0      pastries          croissant
# 12691  CUED_REC_WORD  1.652297e+12      0       syringe           vitamins
# 12711  CUED_REC_WORD  1.652297e+12      0       syringe           vitamins
# 12754  CUED_REC_WORD  1.652297e+12      0     asparagus          asparagus
# 16363  CUED_REC_WORD  1.652298e+12      1      ointment           ointment
# 16495  CUED_REC_WORD  1.652298e+12      1  orange_juice       orange_juice
# 16577  CUED_REC_WORD  1.652298e+12      1            <>              socks
# 16609  CUED_REC_WORD  1.652298e+12      1         roses              roses
# 16688  CUED_REC_WORD  1.652298e+12      1       records            records
# 16753  CUED_REC_WORD  1.652298e+12      1          pump               pump
# 16818  CUED_REC_WORD  1.652298e+12      1     train_set          train_set
# 16918  CUED_REC_WORD  1.652298e+12      1            <>             bagels
# 16989  CUED_REC_WORD  1.652298e+12      1            <>       punching_bag
# 17057  CUED_REC_WORD  1.652298e+12      1            <>            nailgun
# 17125  CUED_REC_WORD  1.652298e+12      1            <>  hair_straightener
# 17202  CUED_REC_WORD  1.652298e+12      1            <>               cups
# 20508  CUED_REC_WORD  1.652298e+12      2            <>               eggs
# 20540  CUED_REC_WORD  1.652298e+12      2       pendant            pendant
# 20638  CUED_REC_WORD  1.652298e+12      2          rope               rope
# 20740  CUED_REC_WORD  1.652298e+12      2   baking_soda        baking_soda
# 20829  CUED_REC_WORD  1.652298e+12      2            <>             lotion
# 20901  CUED_REC_WORD  1.652298e+12      2            <>               yoyo
# 21059  CUED_REC_WORD  1.652298e+12      2            <>             olives
# 21136  CUED_REC_WORD  1.652298e+12      2            <>              purse
# 21203  CUED_REC_WORD  1.652298e+12      2            <>             parrot
# 21303  CUED_REC_WORD  1.652298e+12      2            <>               bell
# 21401  CUED_REC_WORD  1.652299e+12      2            <>             fabric
# 21472  CUED_REC_WORD  1.652299e+12      2        lotion               cape
#
#        serialpos      cued_store          store          store position  \
# 11955          8       bike shop      bike shop   (14.49, 2.27, -33.74)
# 12025          2            cafe           cafe   (36.74, -1.91, 59.06)
# 12092          3        pizzeria       pizzeria  (-14.25, 0.00, -12.89)
# 12197       -999   jewelry store            nan                     nan
# 12225         12       pet store      pet store   (-3.07, 0.00, -58.51)
# 12289          7             gym            gym    (58.31, 4.05, 27.93)
# 12371          9      craft shop     craft shop   (35.40, 0.00, -33.11)
# 12475       -999     barber shop            nan                     nan
# 12543       -999         dentist            nan                     nan
# 12576          2          bakery           cafe   (36.74, -1.91, 59.06)
# 12691         10        pharmacy        dentist   (32.20, 0.33, -60.90)
# 12711         10        pharmacy        dentist   (32.20, 0.33, -60.90)
# 12754          4   grocery store  grocery store  (-60.00, 0.00, -11.50)
# 16363          2        pharmacy       pharmacy    (-9.09, 0.00, 17.86)
# 16495          4   grocery store  grocery store  (-60.00, 0.00, -11.50)
# 16577       -999  clothing store            nan                     nan
# 16609          1         florist        florist   (62.34, 0.00, -33.51)
# 16688         10     music store    music store  (-38.95, 0.00, -61.87)
# 16753         12       bike shop      bike shop   (14.49, 2.27, -33.74)
# 16818          3       toy store      toy store  (-29.57, 1.89, -37.24)
# 16918       -999          bakery            nan                     nan
# 16989       -999             gym            nan                     nan
# 17057       -999  hardware store            nan                     nan
# 17125       -999     barber shop            nan                     nan
# 17202       -999            cafe            nan                     nan
# 20508       -999   grocery store            nan                     nan
# 20540          3   jewelry store  jewelry store    (35.06, 0.00, 26.66)
# 20638          6             gym            gym    (58.31, 4.05, 27.93)
# 20740          4          bakery         bakery    (59.29, 4.65, -9.16)
# 20829       -999        pharmacy            nan                     nan
# 20901       -999       toy store            nan                     nan
# 21059       -999        pizzeria            nan                     nan
# 21136       -999  clothing store            nan                     nan
# 21203       -999       pet store            nan                     nan
# 21303       -999       bike shop            nan                     nan
# 21401       -999      craft shop            nan                     nan
# 21472          9     barber shop       pharmacy    (-9.09, 0.00, 17.86)
#
#       player position  positionX  positionZ  correct direction (degrees)  \
# 11955             NaN        NaN        NaN                          NaN
# 12025             NaN        NaN        NaN                          NaN
# 12092             NaN        NaN        NaN                          NaN
# 12197             NaN        NaN        NaN                          NaN
# 12225             NaN        NaN        NaN                          NaN
# 12289             NaN        NaN        NaN                          NaN
# 12371             NaN        NaN        NaN                          NaN
# 12475             NaN        NaN        NaN                          NaN
# 12543             NaN        NaN        NaN                          NaN
# 12576             NaN        NaN        NaN                          NaN
# 12691             NaN        NaN        NaN                          NaN
# 12711             NaN        NaN        NaN                          NaN
# 12754             NaN        NaN        NaN                          NaN
# 16363             NaN        NaN        NaN                          NaN
# 16495             NaN        NaN        NaN                          NaN
# 16577             NaN        NaN        NaN                          NaN
# 16609             NaN        NaN        NaN                          NaN
# 16688             NaN        NaN        NaN                          NaN
# 16753             NaN        NaN        NaN                          NaN
# 16818             NaN        NaN        NaN                          NaN
# 16918             NaN        NaN        NaN                          NaN
# 16989             NaN        NaN        NaN                          NaN
# 17057             NaN        NaN        NaN                          NaN
# 17125             NaN        NaN        NaN                          NaN
# 17202             NaN        NaN        NaN                          NaN
# 20508             NaN        NaN        NaN                          NaN
# 20540             NaN        NaN        NaN                          NaN
# 20638             NaN        NaN        NaN                          NaN
# 20740             NaN        NaN        NaN                          NaN
# 20829             NaN        NaN        NaN                          NaN
# 20901             NaN        NaN        NaN                          NaN
# 21059             NaN        NaN        NaN                          NaN
# 21136             NaN        NaN        NaN                          NaN
# 21203             NaN        NaN        NaN                          NaN
# 21303             NaN        NaN        NaN                          NaN
# 21401             NaN        NaN        NaN                          NaN
# 21472             NaN        NaN        NaN                          NaN
#
#        pointed direction (degrees) response  key code subject session  \
# 11955                          NaN      NaN       NaN  PILOT3       0
# 12025                          NaN      NaN       NaN  PILOT3       0
# 12092                          NaN      NaN       NaN  PILOT3       0
# 12197                          NaN      NaN       NaN  PILOT3       0
# 12225                          NaN      NaN       NaN  PILOT3       0
# 12289                          NaN      NaN       NaN  PILOT3       0
# 12371                          NaN      NaN       NaN  PILOT3       0
# 12475                          NaN      NaN       NaN  PILOT3       0
# 12543                          NaN      NaN       NaN  PILOT3       0
# 12576                          NaN      NaN       NaN  PILOT3       0
# 12691                          NaN      NaN       NaN  PILOT3       0
# 12711                          NaN      NaN       NaN  PILOT3       0
# 12754                          NaN      NaN       NaN  PILOT3       0
# 16363                          NaN      NaN       NaN  PILOT3       0
# 16495                          NaN      NaN       NaN  PILOT3       0
# 16577                          NaN      NaN       NaN  PILOT3       0
# 16609                          NaN      NaN       NaN  PILOT3       0
# 16688                          NaN      NaN       NaN  PILOT3       0
# 16753                          NaN      NaN       NaN  PILOT3       0
# 16818                          NaN      NaN       NaN  PILOT3       0
# 16918                          NaN      NaN       NaN  PILOT3       0
# 16989                          NaN      NaN       NaN  PILOT3       0
# 17057                          NaN      NaN       NaN  PILOT3       0
# 17125                          NaN      NaN       NaN  PILOT3       0
# 17202                          NaN      NaN       NaN  PILOT3       0
# 20508                          NaN      NaN       NaN  PILOT3       0
# 20540                          NaN      NaN       NaN  PILOT3       0
# 20638                          NaN      NaN       NaN  PILOT3       0
# 20740                          NaN      NaN       NaN  PILOT3       0
# 20829                          NaN      NaN       NaN  PILOT3       0
# 20901                          NaN      NaN       NaN  PILOT3       0
# 21059                          NaN      NaN       NaN  PILOT3       0
# 21136                          NaN      NaN       NaN  PILOT3       0
# 21203                          NaN      NaN       NaN  PILOT3       0
# 21303                          NaN      NaN       NaN  PILOT3       0
# 21401                          NaN      NaN       NaN  PILOT3       0
# 21472                          NaN      NaN       NaN  PILOT3       0
#
#        recalled  intrusion  itemno keypress_code keypress  keypress_mstime  \
# 11955      -999       -999      66           NaN      NaN              NaN
# 12025      -999       -999     153           NaN     True     1.652297e+12
# 12092      -999       -999       6           NaN      NaN              NaN
# 12197      -999       -999      -1           NaN      NaN              NaN
# 12225      -999       -999      96           NaN      NaN              NaN
# 12289      -999       -999      85           NaN     True     1.652297e+12
# 12371      -999       -999     128           NaN      NaN              NaN
# 12475      -999       -999      -1           NaN      NaN              NaN
# 12543      -999       -999      -1           NaN      NaN              NaN
# 12576      -999       -999     153           NaN     True     1.652297e+12
# 12691      -999       -999     211           NaN     True     1.652297e+12
# 12711      -999       -999     211           NaN      NaN              NaN
# 12754      -999       -999       9           NaN      NaN              NaN
# 16363      -999       -999     145           NaN      NaN              NaN
# 16495      -999       -999     147           NaN      NaN              NaN
# 16577      -999       -999      -1           NaN      NaN              NaN
# 16609      -999       -999     179           NaN      NaN              NaN
# 16688      -999       -999     172           NaN      NaN              NaN
# 16753      -999       -999     165           NaN      NaN              NaN
# 16818      -999       -999     224           NaN      NaN              NaN
# 16918      -999       -999      -1           NaN      NaN              NaN
# 16989      -999       -999      -1           NaN      NaN              NaN
# 17057      -999       -999      -1           NaN      NaN              NaN
# 17125      -999       -999      -1           NaN      NaN              NaN
# 17202      -999       -999      -1           NaN      NaN              NaN
# 20508      -999       -999      -1           NaN      NaN              NaN
# 20540      -999       -999     156           NaN      NaN              NaN
# 20638      -999       -999     178           NaN      NaN              NaN
# 20740      -999       -999      14           NaN      NaN              NaN
# 20829      -999       -999      -1           NaN      NaN              NaN
# 20901      -999       -999      -1           NaN      NaN              NaN
# 21059      -999       -999      -1           NaN      NaN              NaN
# 21136      -999       -999      -1           NaN      NaN              NaN
# 21203      -999       -999      -1           NaN      NaN              NaN
# 21303      -999       -999      -1           NaN      NaN              NaN
# 21401      -999       -999      -1           NaN      NaN              NaN
# 21472      -999       -999     126           NaN      NaN              NaN
#
#        keypress_keycode
# 11955               NaN
# 12025               NaN
# 12092               NaN
# 12197               NaN
# 12225               NaN
# 12289               NaN
# 12371               NaN
# 12475               NaN
# 12543               NaN
# 12576               NaN
# 12691               NaN
# 12711               NaN
# 12754               NaN
# 16363               NaN
# 16495               NaN
# 16577               NaN
# 16609               NaN
# 16688               NaN
# 16753               NaN
# 16818               NaN
# 16918               NaN
# 16989               NaN
# 17057               NaN
# 17125               NaN
# 17202               NaN
# 20508               NaN
# 20540               NaN
# 20638               NaN
# 20740               NaN
# 20829               NaN
# 20901               NaN
# 21059               NaN
# 21136               NaN
# 21203               NaN
# 21303               NaN
# 21401               NaN
# 21472               NaN

# %%
a.at[21472, "keypress_code"] = [1,2]
a
# Out:
#                 type        mstime  trial          item          cued_item  \
# 11955  CUED_REC_WORD  1.652297e+12      0        decals             decals
# 12025  CUED_REC_WORD  1.652297e+12      0      pastries           pastries
# 12092  CUED_REC_WORD  1.652297e+12      0     anchovies          anchovies
# 12197  CUED_REC_WORD  1.652297e+12      0            <>              watch
# 12225  CUED_REC_WORD  1.652297e+12      0    guinea_pig         guinea_pig
# 12289  CUED_REC_WORD  1.652297e+12      0     floor_mat          floor_mat
# 12371  CUED_REC_WORD  1.652297e+12      0       markers            markers
# 12475  CUED_REC_WORD  1.652297e+12      0            <>             towels
# 12543  CUED_REC_WORD  1.652297e+12      0            <>            syringe
# 12576  CUED_REC_WORD  1.652297e+12      0      pastries          croissant
# 12691  CUED_REC_WORD  1.652297e+12      0       syringe           vitamins
# 12711  CUED_REC_WORD  1.652297e+12      0       syringe           vitamins
# 12754  CUED_REC_WORD  1.652297e+12      0     asparagus          asparagus
# 16363  CUED_REC_WORD  1.652298e+12      1      ointment           ointment
# 16495  CUED_REC_WORD  1.652298e+12      1  orange_juice       orange_juice
# 16577  CUED_REC_WORD  1.652298e+12      1            <>              socks
# 16609  CUED_REC_WORD  1.652298e+12      1         roses              roses
# 16688  CUED_REC_WORD  1.652298e+12      1       records            records
# 16753  CUED_REC_WORD  1.652298e+12      1          pump               pump
# 16818  CUED_REC_WORD  1.652298e+12      1     train_set          train_set
# 16918  CUED_REC_WORD  1.652298e+12      1            <>             bagels
# 16989  CUED_REC_WORD  1.652298e+12      1            <>       punching_bag
# 17057  CUED_REC_WORD  1.652298e+12      1            <>            nailgun
# 17125  CUED_REC_WORD  1.652298e+12      1            <>  hair_straightener
# 17202  CUED_REC_WORD  1.652298e+12      1            <>               cups
# 20508  CUED_REC_WORD  1.652298e+12      2            <>               eggs
# 20540  CUED_REC_WORD  1.652298e+12      2       pendant            pendant
# 20638  CUED_REC_WORD  1.652298e+12      2          rope               rope
# 20740  CUED_REC_WORD  1.652298e+12      2   baking_soda        baking_soda
# 20829  CUED_REC_WORD  1.652298e+12      2            <>             lotion
# 20901  CUED_REC_WORD  1.652298e+12      2            <>               yoyo
# 21059  CUED_REC_WORD  1.652298e+12      2            <>             olives
# 21136  CUED_REC_WORD  1.652298e+12      2            <>              purse
# 21203  CUED_REC_WORD  1.652298e+12      2            <>             parrot
# 21303  CUED_REC_WORD  1.652298e+12      2            <>               bell
# 21401  CUED_REC_WORD  1.652299e+12      2            <>             fabric
# 21472  CUED_REC_WORD  1.652299e+12      2        lotion               cape
#
#        serialpos      cued_store          store          store position  \
# 11955          8       bike shop      bike shop   (14.49, 2.27, -33.74)
# 12025          2            cafe           cafe   (36.74, -1.91, 59.06)
# 12092          3        pizzeria       pizzeria  (-14.25, 0.00, -12.89)
# 12197       -999   jewelry store            nan                     nan
# 12225         12       pet store      pet store   (-3.07, 0.00, -58.51)
# 12289          7             gym            gym    (58.31, 4.05, 27.93)
# 12371          9      craft shop     craft shop   (35.40, 0.00, -33.11)
# 12475       -999     barber shop            nan                     nan
# 12543       -999         dentist            nan                     nan
# 12576          2          bakery           cafe   (36.74, -1.91, 59.06)
# 12691         10        pharmacy        dentist   (32.20, 0.33, -60.90)
# 12711         10        pharmacy        dentist   (32.20, 0.33, -60.90)
# 12754          4   grocery store  grocery store  (-60.00, 0.00, -11.50)
# 16363          2        pharmacy       pharmacy    (-9.09, 0.00, 17.86)
# 16495          4   grocery store  grocery store  (-60.00, 0.00, -11.50)
# 16577       -999  clothing store            nan                     nan
# 16609          1         florist        florist   (62.34, 0.00, -33.51)
# 16688         10     music store    music store  (-38.95, 0.00, -61.87)
# 16753         12       bike shop      bike shop   (14.49, 2.27, -33.74)
# 16818          3       toy store      toy store  (-29.57, 1.89, -37.24)
# 16918       -999          bakery            nan                     nan
# 16989       -999             gym            nan                     nan
# 17057       -999  hardware store            nan                     nan
# 17125       -999     barber shop            nan                     nan
# 17202       -999            cafe            nan                     nan
# 20508       -999   grocery store            nan                     nan
# 20540          3   jewelry store  jewelry store    (35.06, 0.00, 26.66)
# 20638          6             gym            gym    (58.31, 4.05, 27.93)
# 20740          4          bakery         bakery    (59.29, 4.65, -9.16)
# 20829       -999        pharmacy            nan                     nan
# 20901       -999       toy store            nan                     nan
# 21059       -999        pizzeria            nan                     nan
# 21136       -999  clothing store            nan                     nan
# 21203       -999       pet store            nan                     nan
# 21303       -999       bike shop            nan                     nan
# 21401       -999      craft shop            nan                     nan
# 21472          9     barber shop       pharmacy    (-9.09, 0.00, 17.86)
#
#       player position  positionX  positionZ  correct direction (degrees)  \
# 11955             NaN        NaN        NaN                          NaN
# 12025             NaN        NaN        NaN                          NaN
# 12092             NaN        NaN        NaN                          NaN
# 12197             NaN        NaN        NaN                          NaN
# 12225             NaN        NaN        NaN                          NaN
# 12289             NaN        NaN        NaN                          NaN
# 12371             NaN        NaN        NaN                          NaN
# 12475             NaN        NaN        NaN                          NaN
# 12543             NaN        NaN        NaN                          NaN
# 12576             NaN        NaN        NaN                          NaN
# 12691             NaN        NaN        NaN                          NaN
# 12711             NaN        NaN        NaN                          NaN
# 12754             NaN        NaN        NaN                          NaN
# 16363             NaN        NaN        NaN                          NaN
# 16495             NaN        NaN        NaN                          NaN
# 16577             NaN        NaN        NaN                          NaN
# 16609             NaN        NaN        NaN                          NaN
# 16688             NaN        NaN        NaN                          NaN
# 16753             NaN        NaN        NaN                          NaN
# 16818             NaN        NaN        NaN                          NaN
# 16918             NaN        NaN        NaN                          NaN
# 16989             NaN        NaN        NaN                          NaN
# 17057             NaN        NaN        NaN                          NaN
# 17125             NaN        NaN        NaN                          NaN
# 17202             NaN        NaN        NaN                          NaN
# 20508             NaN        NaN        NaN                          NaN
# 20540             NaN        NaN        NaN                          NaN
# 20638             NaN        NaN        NaN                          NaN
# 20740             NaN        NaN        NaN                          NaN
# 20829             NaN        NaN        NaN                          NaN
# 20901             NaN        NaN        NaN                          NaN
# 21059             NaN        NaN        NaN                          NaN
# 21136             NaN        NaN        NaN                          NaN
# 21203             NaN        NaN        NaN                          NaN
# 21303             NaN        NaN        NaN                          NaN
# 21401             NaN        NaN        NaN                          NaN
# 21472             NaN        NaN        NaN                          NaN
#
#        pointed direction (degrees) response  key code subject session  \
# 11955                          NaN      NaN       NaN  PILOT3       0
# 12025                          NaN      NaN       NaN  PILOT3       0
# 12092                          NaN      NaN       NaN  PILOT3       0
# 12197                          NaN      NaN       NaN  PILOT3       0
# 12225                          NaN      NaN       NaN  PILOT3       0
# 12289                          NaN      NaN       NaN  PILOT3       0
# 12371                          NaN      NaN       NaN  PILOT3       0
# 12475                          NaN      NaN       NaN  PILOT3       0
# 12543                          NaN      NaN       NaN  PILOT3       0
# 12576                          NaN      NaN       NaN  PILOT3       0
# 12691                          NaN      NaN       NaN  PILOT3       0
# 12711                          NaN      NaN       NaN  PILOT3       0
# 12754                          NaN      NaN       NaN  PILOT3       0
# 16363                          NaN      NaN       NaN  PILOT3       0
# 16495                          NaN      NaN       NaN  PILOT3       0
# 16577                          NaN      NaN       NaN  PILOT3       0
# 16609                          NaN      NaN       NaN  PILOT3       0
# 16688                          NaN      NaN       NaN  PILOT3       0
# 16753                          NaN      NaN       NaN  PILOT3       0
# 16818                          NaN      NaN       NaN  PILOT3       0
# 16918                          NaN      NaN       NaN  PILOT3       0
# 16989                          NaN      NaN       NaN  PILOT3       0
# 17057                          NaN      NaN       NaN  PILOT3       0
# 17125                          NaN      NaN       NaN  PILOT3       0
# 17202                          NaN      NaN       NaN  PILOT3       0
# 20508                          NaN      NaN       NaN  PILOT3       0
# 20540                          NaN      NaN       NaN  PILOT3       0
# 20638                          NaN      NaN       NaN  PILOT3       0
# 20740                          NaN      NaN       NaN  PILOT3       0
# 20829                          NaN      NaN       NaN  PILOT3       0
# 20901                          NaN      NaN       NaN  PILOT3       0
# 21059                          NaN      NaN       NaN  PILOT3       0
# 21136                          NaN      NaN       NaN  PILOT3       0
# 21203                          NaN      NaN       NaN  PILOT3       0
# 21303                          NaN      NaN       NaN  PILOT3       0
# 21401                          NaN      NaN       NaN  PILOT3       0
# 21472                          NaN      NaN       NaN  PILOT3       0
#
#        recalled  intrusion  itemno keypress_code keypress  keypress_mstime  \
# 11955      -999       -999      66           NaN      NaN              NaN
# 12025      -999       -999     153           NaN     True     1.652297e+12
# 12092      -999       -999       6           NaN      NaN              NaN
# 12197      -999       -999      -1           NaN      NaN              NaN
# 12225      -999       -999      96           NaN      NaN              NaN
# 12289      -999       -999      85           NaN     True     1.652297e+12
# 12371      -999       -999     128           NaN      NaN              NaN
# 12475      -999       -999      -1           NaN      NaN              NaN
# 12543      -999       -999      -1           NaN      NaN              NaN
# 12576      -999       -999     153           NaN     True     1.652297e+12
# 12691      -999       -999     211           NaN     True     1.652297e+12
# 12711      -999       -999     211           NaN      NaN              NaN
# 12754      -999       -999       9           NaN      NaN              NaN
# 16363      -999       -999     145           NaN      NaN              NaN
# 16495      -999       -999     147           NaN      NaN              NaN
# 16577      -999       -999      -1           NaN      NaN              NaN
# 16609      -999       -999     179           NaN      NaN              NaN
# 16688      -999       -999     172           NaN      NaN              NaN
# 16753      -999       -999     165           NaN      NaN              NaN
# 16818      -999       -999     224           NaN      NaN              NaN
# 16918      -999       -999      -1           NaN      NaN              NaN
# 16989      -999       -999      -1           NaN      NaN              NaN
# 17057      -999       -999      -1           NaN      NaN              NaN
# 17125      -999       -999      -1           NaN      NaN              NaN
# 17202      -999       -999      -1           NaN      NaN              NaN
# 20508      -999       -999      -1           NaN      NaN              NaN
# 20540      -999       -999     156           NaN      NaN              NaN
# 20638      -999       -999     178           NaN      NaN              NaN
# 20740      -999       -999      14           NaN      NaN              NaN
# 20829      -999       -999      -1           NaN      NaN              NaN
# 20901      -999       -999      -1           NaN      NaN              NaN
# 21059      -999       -999      -1           NaN      NaN              NaN
# 21136      -999       -999      -1           NaN      NaN              NaN
# 21203      -999       -999      -1           NaN      NaN              NaN
# 21303      -999       -999      -1           NaN      NaN              NaN
# 21401      -999       -999      -1           NaN      NaN              NaN
# 21472      -999       -999     126        [1, 2]      NaN              NaN
#
#        keypress_keycode
# 11955               NaN
# 12025               NaN
# 12092               NaN
# 12197               NaN
# 12225               NaN
# 12289               NaN
# 12371               NaN
# 12475               NaN
# 12543               NaN
# 12576               NaN
# 12691               NaN
# 12711               NaN
# 12754               NaN
# 16363               NaN
# 16495               NaN
# 16577               NaN
# 16609               NaN
# 16688               NaN
# 16753               NaN
# 16818               NaN
# 16918               NaN
# 16989               NaN
# 17057               NaN
# 17125               NaN
# 17202               NaN
# 20508               NaN
# 20540               NaN
# 20638               NaN
# 20740               NaN
# 20829               NaN
# 20901               NaN
# 21059               NaN
# 21136               NaN
# 21203               NaN
# 21303               NaN
# 21401               NaN
# 21472               NaN

# %%
    ###############################################################################################
    # add EFR presses
    ###############################################################################################
    tmp["keypress_code"] = np.nan
    tmp = tmp.astype({"keypress_code":object})
    
    # FREE RECALL
    rec_evs = tmp.query('type == "REC_WORD" | type == "REC_STOP"')
    rec_evs_index = rec_evs.index

    for i in range(len(rec_evs)-1):

        curr_row = rec_evs.iloc[i]
        if curr_row.type != "REC_WORD":
            continue
        next_row = rec_evs.iloc[i+1]

        curr_time = curr_row.mstime
        next_time = next_row.mstime

        EFR_candidates = tmp.query('(type == "keypress" | type == "key press/release") & \
                                   mstime > @curr_time & mstime < @next_time')
        if len(EFR_candidates.query('type == "keypress"')) > 0:
            responses = EFR_candidates["key code"].unique()
            responses = responses[~np.isnan(responses)]
            response_time = EFR_candidates.query('type == "keypress"').mstime.values[0]

            tmp.at[rec_evs_index[i], "keypress"] = True
            tmp.at[rec_evs_index[i], "keypress_code"] = responses.tolist()
            tmp.at[rec_evs_index[i], "keypress_mstime"] = response_time

    # CUED RECALL
    cued_rec_evs = tmp.query('type == "CUED_REC_WORD" | type == "CUED_REC_STOP"')
    cued_rec_evs_index = cued_rec_evs.index

    for i in range(len(cued_rec_evs)-1):

        curr_row = cued_rec_evs.iloc[i]
        if curr_row.type != "CUED_REC_WORD":
            continue
        next_row = cued_rec_evs.iloc[i+1]

        curr_time = curr_row.mstime
        next_time = next_row.mstime

        EFR_candidates = tmp.query('(type == "keypress" | type == "key press/release") & \
                                    mstime > @curr_time & mstime < @next_time')
        if len(EFR_candidates.query('type == "keypress"')) > 0:
            responses = EFR_candidates["key code"].unique()
            responses = responses[~np.isnan(responses)]
            response_time = EFR_candidates.query('type == "keypress"').mstime.values[0]

            tmp.at[cued_rec_evs_index[i], "keypress"] = True
            tmp.at[cued_rec_evs_index[i], "keypress_code"] = responses.tolist()
            tmp.at[cued_rec_evs_index[i], "keypress_mstime"] = response_time

    # FINAL STORE RECALL
    store_rec_evs = tmp.query('type == "FSR_REC_WORD" | type == "FSR_REC_STOP"')
    store_rec_evs_index = store_rec_evs.index

    for i in range(len(store_rec_evs)-1):

        curr_row = store_rec_evs.iloc[i]
        if curr_row.type != "FSR_REC_WORD":
            continue
        next_row = store_rec_evs.iloc[i+1]

        curr_time = curr_row.mstime
        next_time = next_row.mstime

        EFR_candidates = tmp.query('(type == "keypress" | type == "key press/release") & \
                                    mstime > @curr_time & mstime < @next_time')
        if len(EFR_candidates.query('type == "keypress"')) > 0:
            responses = EFR_candidates["key code"].unique()
            responses = responses[~np.isnan(responses)]
            response_time = EFR_candidates.query('type == "keypress"').mstime.values[0]

            tmp.at[store_rec_evs_index[i], "keypress"] = True
            tmp.at[store_rec_evs_index[i], "keypress_code"] = responses.tolist()
            tmp.at[store_rec_evs_index[i], "keypress_mstime"] = response_time

    # FINAL FREE RECALL
    final_rec_evs = tmp.query('type == "FFR_REC_WORD" | type == "FFR_REC_STOP"')
    final_rec_evs_index = final_rec_evs.index

    for i in range(len(final_rec_evs)-1):

        curr_row = final_rec_evs.iloc[i]
        if curr_row.type != "FFR_REC_WORD":
            continue
        next_row = final_rec_evs.iloc[i+1]

        curr_time = curr_row.mstime
        next_time = next_row.mstime

        EFR_candidates = tmp.query('(type == "keypress" | type == "key press/release") & \
                                    mstime > @curr_time & mstime < @next_time')
        if len(EFR_candidates.query('type == "keypress"')) > 0:
            responses = EFR_candidates["key code"].unique()
            responses = responses[~np.isnan(responses)]
            response_time = EFR_candidates.query('type == "keypress"').mstime.values[0]

            tmp.at[final_rec_evs_index[i], "keypress"] = True
            tmp.at[final_rec_evs_index[i], "keypress_code"] = responses.tolist()
            tmp.at[final_rec_evs_index[i], "keypress_mstime"] = response_time
# Out:
# ['/scratch/new_courier_pilot/PILOT1/session_0', '/scratch/new_courier_pilot/PILOT2/session_0', '/scratch/new_courier_pilot/PILOT3/session_0', '/scratch/new_courier_pilot/PILOT4/session_1', '/scratch/new_courier_pilot/PILOT4/session_0']
# subject PILOT1, sess 0
# subject PILOT2, sess 0
# subject PILOT3, sess 0
# subject PILOT4, sess 1
# subject PILOT4, sess 0

# %%
tmp.query('type == "REC_WORD"')
# Out:
#            type        mstime  trial             item cued_item  serialpos  \
# 11728  REC_WORD  1.652717e+12      0    x-ray_machine       NaN         12
# 11741  REC_WORD  1.652717e+12      0       mistletoes       NaN       -999
# 11756  REC_WORD  1.652717e+12      0            gauze       NaN          8
# 11821  REC_WORD  1.652717e+12      0         scissors       NaN       -999
# 11848  REC_WORD  1.652717e+12      0             milk       NaN       -999
# 11873  REC_WORD  1.652717e+12      0  chocolate_chips       NaN         11
# 11953  REC_WORD  1.652717e+12      0  chocolate_chips       NaN         11
# 12126  REC_WORD  1.652717e+12      0             menu       NaN          4
# 12194  REC_WORD  1.652717e+12      0       inflatable       NaN       -999
# 45516  REC_WORD  1.652722e+12      1  training_wheels       NaN         12
# 45531  REC_WORD  1.652722e+12      1            dough       NaN         10
# 45541  REC_WORD  1.652722e+12      1         vitamins       NaN          9
# 45568  REC_WORD  1.652722e+12      1  training_wheels       NaN         12
# 45603  REC_WORD  1.652722e+12      1            flour       NaN          8
# 45670  REC_WORD  1.652722e+12      1       guinea_pig       NaN         11
# 45728  REC_WORD  1.652722e+12      1         titanium       NaN       -999
# 45884  REC_WORD  1.652722e+12      1       guinea_pig       NaN         11
# 45993  REC_WORD  1.652722e+12      1           guitar       NaN       -999
#
#       cued_store      store          store position player position  \
# 11728        NaN    dentist   (32.20, 0.33, -60.90)             NaN
# 11741        NaN        nan                     nan             NaN
# 11756        NaN   pharmacy    (-9.09, 0.00, 17.86)             NaN
# 11821        NaN        nan                     nan             NaN
# 11848        NaN        nan                     nan             NaN
# 11873        NaN     bakery    (59.29, 4.65, -9.16)             NaN
# 11953        NaN     bakery    (59.29, 4.65, -9.16)             NaN
# 12126        NaN   pizzeria  (-14.25, 0.00, -12.89)             NaN
# 12194        NaN        nan                     nan             NaN
# 45516        NaN  bike shop   (14.49, 2.27, -33.74)             NaN
# 45531        NaN   pizzeria  (-14.25, 0.00, -12.89)             NaN
# 45541        NaN   pharmacy    (-9.09, 0.00, 17.86)             NaN
# 45568        NaN  bike shop   (14.49, 2.27, -33.74)             NaN
# 45603        NaN     bakery    (59.29, 4.65, -9.16)             NaN
# 45670        NaN  pet store   (-3.07, 0.00, -58.51)             NaN
# 45728        NaN        nan                     nan             NaN
# 45884        NaN  pet store   (-3.07, 0.00, -58.51)             NaN
# 45993        NaN        nan                     nan             NaN
#
#        positionX  positionZ  correct direction (degrees)  \
# 11728        NaN        NaN                          NaN
# 11741        NaN        NaN                          NaN
# 11756        NaN        NaN                          NaN
# 11821        NaN        NaN                          NaN
# 11848        NaN        NaN                          NaN
# 11873        NaN        NaN                          NaN
# 11953        NaN        NaN                          NaN
# 12126        NaN        NaN                          NaN
# 12194        NaN        NaN                          NaN
# 45516        NaN        NaN                          NaN
# 45531        NaN        NaN                          NaN
# 45541        NaN        NaN                          NaN
# 45568        NaN        NaN                          NaN
# 45603        NaN        NaN                          NaN
# 45670        NaN        NaN                          NaN
# 45728        NaN        NaN                          NaN
# 45884        NaN        NaN                          NaN
# 45993        NaN        NaN                          NaN
#
#        pointed direction (degrees) response  key code subject session  \
# 11728                          NaN      NaN       NaN  PILOT4       0
# 11741                          NaN      NaN       NaN  PILOT4       0
# 11756                          NaN      NaN       NaN  PILOT4       0
# 11821                          NaN      NaN       NaN  PILOT4       0
# 11848                          NaN      NaN       NaN  PILOT4       0
# 11873                          NaN      NaN       NaN  PILOT4       0
# 11953                          NaN      NaN       NaN  PILOT4       0
# 12126                          NaN      NaN       NaN  PILOT4       0
# 12194                          NaN      NaN       NaN  PILOT4       0
# 45516                          NaN      NaN       NaN  PILOT4       0
# 45531                          NaN      NaN       NaN  PILOT4       0
# 45541                          NaN      NaN       NaN  PILOT4       0
# 45568                          NaN      NaN       NaN  PILOT4       0
# 45603                          NaN      NaN       NaN  PILOT4       0
# 45670                          NaN      NaN       NaN  PILOT4       0
# 45728                          NaN      NaN       NaN  PILOT4       0
# 45884                          NaN      NaN       NaN  PILOT4       0
# 45993                          NaN      NaN       NaN  PILOT4       0
#
#        recalled  intrusion  itemno  keypress_code keypress  keypress_mstime
# 11728      -999         -1     235            NaN      NaN              NaN
# 11741      -999          0      -1            NaN      NaN              NaN
# 11756      -999         -1      92            NaN      NaN              NaN
# 11821      -999         -1     186         [98.0]     True     1.652717e+12
# 11848      -999         -1     132         [98.0]     True     1.652717e+12
# 11873      -999         -1      47            NaN      NaN              NaN
# 11953      -999         -1      47         [98.0]     True     1.652717e+12
# 12126      -999         -1     130            NaN      NaN              NaN
# 12194      -999          0      -1         [98.0]     True     1.652717e+12
# 45516      -999         -1     225            NaN      NaN              NaN
# 45531      -999         -1      70            NaN      NaN              NaN
# 45541      -999         -1     229            NaN      NaN              NaN
# 45568      -999         -1     225  [120.0, 98.0]     True     1.652722e+12
# 45603      -999         -1      87            NaN      NaN              NaN
# 45670      -999         -1      96            NaN      NaN              NaN
# 45728      -999          0      -1         [98.0]     True     1.652722e+12
# 45884      -999         -1      96         [98.0]     True     1.652722e+12
# 45993      -999         -1      97         [98.0]     True     1.652722e+12

# %%
data = []
sub = "PILOT2"

data_dir = "/scratch/new_courier_pilot/"

for line in open("/scratch/new_courier_pilot/{}/session_0/session.jsonl".format(sub), "r"):
    
    if '"point condition":SerialPosition,' in line:
        line = line.replace('"point condition":SerialPosition,', '')
    elif '"point condition":SpatialPosition,' in line:
        line = line.replace('"point condition":SpatialPosition,', '')
    elif '"point condition":Random,' in line:
        line = line.replace('"point condition":Random,', '')
    
    data_dict = json.loads(line)
    
    data.append(data_dict)

for d in data:
    for k,v in d["data"].items():
        d[k] = v

df = pd.DataFrame(data)

# %%
column_names = ["type", "time", "trial number", "item name", "item", "serial position", "store", "store name", "store position", 
                "player position", "positionX", "positionZ", "correct direction (degrees)", "pointed direction (degrees)", "response"]
df = df[column_names]
df = df.rename(columns={
                        'trial number': 'trial',
                        'time': 'mstime',
                        'serial position': 'serialpos',
                        'item': 'cued_item',
                        'store': 'cued_store',
                        'store name': 'store',
                        'item name': 'item'
                        })
df["subject"] = sub

# change the type name to match lab's data frame formatting
df = df.replace({'type': {'object presentation begins': 'WORD', 
                     'free recall': 'REC_WORD',
                     'start free recall': 'REC_START',
                     'end free recall': 'REC_STOP',
                     'start cued recall typing': 'CUED_REC_CUE',
                     'cued recall': 'CUED_REC_WORD',
                     'final store recall': 'SR_REC_WORD', 
                     'final object recall': 'FFR_REC_WORD'
                    }})

# %% [markdown]
# # Free Recall Processing

# %%
# now get recall dataframe ready to insert
recall_df = pd.DataFrame(columns = df.columns)

count = 0
rec_starts = df.query('type == "REC_START"')
for i, row in rec_starts.iterrows():
    sub = rec_starts['subject'].unique()[0]
    
    if row["type"] == "REC_START":
        # first REC_START will indicate practice recall stage
        if count > 0:
            rec_start_time = row.mstime
            
            # let's load appropriate .ann files
            data_dir = "/scratch/new_courier_pilot/{}/session_0/{}.ann".format(sub, count-1)
            with open(data_dir, "r") as file:
                lines = file.readlines()
                for line in lines:
                    if line[0] != "#":
                        recall_info = line.strip("\n").split("\t")
                        
                        if len(recall_info) == 3:
                            rectime = float(recall_info[0]) + rec_start_time
                            item = recall_info[2].lower()
                            itemno = recall_info[1]
                            
                            recall_df = recall_df.append({"type":"REC_WORD", "mstime":rectime, "trial":count-1, 
                                                          "item":item, "itemno":itemno, "subject":sub}, ignore_index=True)
    
        count += 1
        
recall_df
# Out:
#         type        mstime trial              item  cued_item  serialpos  \
# 0   REC_WORD  1.649794e+12     0              eggs        NaN        NaN
# 1   REC_WORD  1.649794e+12     0         hula_hoop        NaN        NaN
# 2   REC_WORD  1.649794e+12     0              rope        NaN        NaN
# 3   REC_WORD  1.649794e+12     0             locks        NaN        NaN
# 4   REC_WORD  1.649794e+12     0         saxophone        NaN        NaN
# 5   REC_WORD  1.649794e+12     0      cotton_balls        NaN        NaN
# 6   REC_WORD  1.649794e+12     0       sweet-n-low        NaN        NaN
# 7   REC_WORD  1.649794e+12     0         head_band        NaN        NaN
# 8   REC_WORD  1.649794e+12     0           muffins        NaN        NaN
# 9   REC_WORD  1.649794e+12     0          bracelet        NaN        NaN
# 10  REC_WORD  1.649794e+12     1             syrup        NaN        NaN
# 11  REC_WORD  1.649794e+12     1            ribbon        NaN        NaN
# 12  REC_WORD  1.649794e+12     1              comb        NaN        NaN
# 13  REC_WORD  1.649794e+12     1              roll        NaN        NaN
# 14  REC_WORD  1.649794e+12     1  contact_solution        NaN        NaN
# 15  REC_WORD  1.649794e+12     1    stuffed_animal        NaN        NaN
# 16  REC_WORD  1.649794e+12     1          platinum        NaN        NaN
# 17  REC_WORD  1.649794e+12     1     medicine_ball        NaN        NaN
# 18  REC_WORD  1.649794e+12     1            screws        NaN        NaN
# 19  REC_WORD  1.649794e+12     1              soil        NaN        NaN
#
#     cued_store  store  store position  player position  positionX  positionZ  \
# 0          NaN    NaN             NaN              NaN        NaN        NaN
# 1          NaN    NaN             NaN              NaN        NaN        NaN
# 2          NaN    NaN             NaN              NaN        NaN        NaN
# 3          NaN    NaN             NaN              NaN        NaN        NaN
# 4          NaN    NaN             NaN              NaN        NaN        NaN
# 5          NaN    NaN             NaN              NaN        NaN        NaN
# 6          NaN    NaN             NaN              NaN        NaN        NaN
# 7          NaN    NaN             NaN              NaN        NaN        NaN
# 8          NaN    NaN             NaN              NaN        NaN        NaN
# 9          NaN    NaN             NaN              NaN        NaN        NaN
# 10         NaN    NaN             NaN              NaN        NaN        NaN
# 11         NaN    NaN             NaN              NaN        NaN        NaN
# 12         NaN    NaN             NaN              NaN        NaN        NaN
# 13         NaN    NaN             NaN              NaN        NaN        NaN
# 14         NaN    NaN             NaN              NaN        NaN        NaN
# 15         NaN    NaN             NaN              NaN        NaN        NaN
# 16         NaN    NaN             NaN              NaN        NaN        NaN
# 17         NaN    NaN             NaN              NaN        NaN        NaN
# 18         NaN    NaN             NaN              NaN        NaN        NaN
# 19         NaN    NaN             NaN              NaN        NaN        NaN
#
#     correct direction (degrees)  pointed direction (degrees)  response  \
# 0                           NaN                          NaN       NaN
# 1                           NaN                          NaN       NaN
# 2                           NaN                          NaN       NaN
# 3                           NaN                          NaN       NaN
# 4                           NaN                          NaN       NaN
# 5                           NaN                          NaN       NaN
# 6                           NaN                          NaN       NaN
# 7                           NaN                          NaN       NaN
# 8                           NaN                          NaN       NaN
# 9                           NaN                          NaN       NaN
# 10                          NaN                          NaN       NaN
# 11                          NaN                          NaN       NaN
# 12                          NaN                          NaN       NaN
# 13                          NaN                          NaN       NaN
# 14                          NaN                          NaN       NaN
# 15                          NaN                          NaN       NaN
# 16                          NaN                          NaN       NaN
# 17                          NaN                          NaN       NaN
# 18                          NaN                          NaN       NaN
# 19                          NaN                          NaN       NaN
#
#    subject itemno
# 0   PILOT2     77
# 1   PILOT2    113
# 2   PILOT2    178
# 3   PILOT2    124
# 4   PILOT2    183
# 5   PILOT2     58
# 6   PILOT2    210
# 7   PILOT2    110
# 8   PILOT2    136
# 9   PILOT2     28
# 10  PILOT2    212
# 11  PILOT2    175
# 12  PILOT2     52
# 13  PILOT2    177
# 14  PILOT2     56
# 15  PILOT2    204
# 16  PILOT2    161
# 17  PILOT2    129
# 18  PILOT2    189
# 19  PILOT2    197

# %%
# then, fill out the blanks
recall_df["store"] = recall_df["store"].astype(str)
recall_df["store position"] = recall_df["store position"].astype(str)

for i, row in recall_df.iterrows():
    word_evs = df[(df.trial == row.trial) & (df.type == "WORD")]
    
    row_item = row["item"]
    recall_word = word_evs.query('item == @row_item')
    
    if len(recall_word) != 0:        
        serialpos = recall_word["serialpos"].values[0]
        store = recall_word["store"].values[0]
        store_position = recall_word["store position"].values[0]
        
        recall_df.at[i, "serialpos"] = serialpos
        recall_df.at[i, "store"] = store
        recall_df.at[i, "store position"] = store_position
        
    else:
        recall_df.at[i, "serialpos"] = -1
    
recall_df
# Out:
#         type        mstime trial              item  cued_item  serialpos  \
# 0   REC_WORD  1.649794e+12     0              eggs        NaN       -1.0
# 1   REC_WORD  1.649794e+12     0         hula_hoop        NaN        9.0
# 2   REC_WORD  1.649794e+12     0              rope        NaN       11.0
# 3   REC_WORD  1.649794e+12     0             locks        NaN       10.0
# 4   REC_WORD  1.649794e+12     0         saxophone        NaN        3.0
# 5   REC_WORD  1.649794e+12     0      cotton_balls        NaN        5.0
# 6   REC_WORD  1.649794e+12     0       sweet-n-low        NaN        2.0
# 7   REC_WORD  1.649794e+12     0         head_band        NaN        4.0
# 8   REC_WORD  1.649794e+12     0           muffins        NaN       -1.0
# 9   REC_WORD  1.649794e+12     0          bracelet        NaN        8.0
# 10  REC_WORD  1.649794e+12     1             syrup        NaN       12.0
# 11  REC_WORD  1.649794e+12     1            ribbon        NaN       11.0
# 12  REC_WORD  1.649794e+12     1              comb        NaN        3.0
# 13  REC_WORD  1.649794e+12     1              roll        NaN        4.0
# 14  REC_WORD  1.649794e+12     1  contact_solution        NaN        1.0
# 15  REC_WORD  1.649794e+12     1    stuffed_animal        NaN        6.0
# 16  REC_WORD  1.649794e+12     1          platinum        NaN        5.0
# 17  REC_WORD  1.649794e+12     1     medicine_ball        NaN        9.0
# 18  REC_WORD  1.649794e+12     1            screws        NaN        7.0
# 19  REC_WORD  1.649794e+12     1              soil        NaN       10.0
#
#     cued_store           store          store position  player position  \
# 0          NaN             nan                     nan              NaN
# 1          NaN       toy store   (-3.07, 0.00, -58.51)              NaN
# 2          NaN             gym  (-38.95, 0.00, -61.87)              NaN
# 3          NaN       bike shop   (-31.82, 4.70, 55.71)              NaN
# 4          NaN     music store  (-29.57, 1.89, -37.24)              NaN
# 5          NaN         dentist  (14.55, -0.04, -58.79)              NaN
# 6          NaN            cafe    (58.31, 4.05, 27.93)              NaN
# 7          NaN  clothing store  (-60.00, 0.00, -11.50)              NaN
# 8          NaN             nan                     nan              NaN
# 9          NaN   jewelry store   (62.34, 0.00, -33.51)              NaN
# 10         NaN            cafe    (58.31, 4.05, 27.93)              NaN
# 11         NaN      craft shop    (59.29, 4.65, -9.16)              NaN
# 12         NaN     barber shop   (35.40, 0.00, -33.11)              NaN
# 13         NaN          bakery   (14.49, 2.27, -33.74)              NaN
# 14         NaN        pharmacy  (-14.25, 0.00, -12.89)              NaN
# 15         NaN       toy store   (-3.07, 0.00, -58.51)              NaN
# 16         NaN   jewelry store   (62.34, 0.00, -33.51)              NaN
# 17         NaN             gym  (-38.95, 0.00, -61.87)              NaN
# 18         NaN  hardware store    (35.06, 0.00, 26.66)              NaN
# 19         NaN         florist   (36.74, -1.91, 59.06)              NaN
#
#     positionX  positionZ  correct direction (degrees)  \
# 0         NaN        NaN                          NaN
# 1         NaN        NaN                          NaN
# 2         NaN        NaN                          NaN
# 3         NaN        NaN                          NaN
# 4         NaN        NaN                          NaN
# 5         NaN        NaN                          NaN
# 6         NaN        NaN                          NaN
# 7         NaN        NaN                          NaN
# 8         NaN        NaN                          NaN
# 9         NaN        NaN                          NaN
# 10        NaN        NaN                          NaN
# 11        NaN        NaN                          NaN
# 12        NaN        NaN                          NaN
# 13        NaN        NaN                          NaN
# 14        NaN        NaN                          NaN
# 15        NaN        NaN                          NaN
# 16        NaN        NaN                          NaN
# 17        NaN        NaN                          NaN
# 18        NaN        NaN                          NaN
# 19        NaN        NaN                          NaN
#
#     pointed direction (degrees)  response subject itemno
# 0                           NaN       NaN  PILOT2     77
# 1                           NaN       NaN  PILOT2    113
# 2                           NaN       NaN  PILOT2    178
# 3                           NaN       NaN  PILOT2    124
# 4                           NaN       NaN  PILOT2    183
# 5                           NaN       NaN  PILOT2     58
# 6                           NaN       NaN  PILOT2    210
# 7                           NaN       NaN  PILOT2    110
# 8                           NaN       NaN  PILOT2    136
# 9                           NaN       NaN  PILOT2     28
# 10                          NaN       NaN  PILOT2    212
# 11                          NaN       NaN  PILOT2    175
# 12                          NaN       NaN  PILOT2     52
# 13                          NaN       NaN  PILOT2    177
# 14                          NaN       NaN  PILOT2     56
# 15                          NaN       NaN  PILOT2    204
# 16                          NaN       NaN  PILOT2    161
# 17                          NaN       NaN  PILOT2    129
# 18                          NaN       NaN  PILOT2    189
# 19                          NaN       NaN  PILOT2    197

# %% [markdown]
# # Cued Recall Processing

# %%
cued_rec_start = df.query('type == "start cued recall"').mstime.values[1]   ## skip practice cued recall
cued_rec_events = df.query('type == "cued recall recording start" & mstime >= @cued_rec_start')

cued_recall_df = pd.DataFrame(columns = df.columns)

for i, row in cued_rec_events.iterrows():
    sub = row.subject
    trial = int(row.trial)
    cued_item = row.cued_item
    cued_store = row.cued_store
    cued_time = row.mstime
    
    word_evs = df.query('type == "WORD" & subject == @sub & trial == @trial')
    stores = word_evs.store.unique()
    
    if cued_store not in stores:
        continue
    
    # locate the .ann file
    data_dir = "/scratch/new_courier_pilot/{}/session_0/{}-{}.ann".format(sub, trial, cued_store)
    with open(data_dir, "r") as file:
        lines = file.readlines()
        for line in lines:
            if line[0] != "#":
                recall_info = line.strip("\n").split("\t")
                
                if len(recall_info) == 3:
                    rectime = float(recall_info[0]) + cued_time
                    item = recall_info[2].lower()
                    itemno = recall_info[1]
                    
                    cued_recall_df = cued_recall_df.append({"type": "CUED_REC_WORD", "mstime": rectime, "trial": trial, 
                                                            "item": item, "itemno": itemno, "cued_item": cued_item, "cued_store": cued_store, 
                                                            "subject":sub}, ignore_index=True)
    
cued_recall_df
# Out:
#              type        mstime trial              item         cued_item  \
# 0   CUED_REC_WORD  1.649794e+12     0       sweet-n-low       sweet-n-low
# 1   CUED_REC_WORD  1.649794e+12     0             locks             locks
# 2   CUED_REC_WORD  1.649794e+12     0              rope              rope
# 3   CUED_REC_WORD  1.649794e+12     0      cotton_balls      cotton_balls
# 4   CUED_REC_WORD  1.649794e+12     0         head_band         head_band
# 5   CUED_REC_WORD  1.649794e+12     0              mice              mice
# 6   CUED_REC_WORD  1.649794e+12     0                <>       cough_syrup
# 7   CUED_REC_WORD  1.649794e+12     0                <>              yarn
# 8   CUED_REC_WORD  1.649794e+12     0         hula_hoop         hula_hoop
# 9   CUED_REC_WORD  1.649794e+12     0          bracelet          bracelet
# 10  CUED_REC_WORD  1.649794e+12     0                <>              bags
# 11  CUED_REC_WORD  1.649794e+12     0         saxophone         saxophone
# 12  CUED_REC_WORD  1.649794e+12     1    stuffed_animal    stuffed_animal
# 13  CUED_REC_WORD  1.649794e+12     1            tshirt             socks
# 14  CUED_REC_WORD  1.649794e+12     1  contact_solution  contact_solution
# 15  CUED_REC_WORD  1.649795e+12     1            ribbon            ribbon
# 16  CUED_REC_WORD  1.649795e+12     1              comb              comb
# 17  CUED_REC_WORD  1.649795e+12     1          platinum          platinum
# 18  CUED_REC_WORD  1.649795e+12     1              roll              roll
# 19  CUED_REC_WORD  1.649795e+12     1            screws            screws
# 20  CUED_REC_WORD  1.649795e+12     1              soil              soil
# 21  CUED_REC_WORD  1.649795e+12     1             tires            helmet
# 22  CUED_REC_WORD  1.649795e+12     1     medicine_ball     medicine_ball
# 23  CUED_REC_WORD  1.649795e+12     1             syrup             syrup
#
#     serialpos      cued_store  store  store position  player position  \
# 0         NaN            cafe    NaN             NaN              NaN
# 1         NaN       bike shop    NaN             NaN              NaN
# 2         NaN             gym    NaN             NaN              NaN
# 3         NaN         dentist    NaN             NaN              NaN
# 4         NaN  clothing store    NaN             NaN              NaN
# 5         NaN       pet store    NaN             NaN              NaN
# 6         NaN        pharmacy    NaN             NaN              NaN
# 7         NaN      craft shop    NaN             NaN              NaN
# 8         NaN       toy store    NaN             NaN              NaN
# 9         NaN   jewelry store    NaN             NaN              NaN
# 10        NaN   grocery store    NaN             NaN              NaN
# 11        NaN     music store    NaN             NaN              NaN
# 12        NaN       toy store    NaN             NaN              NaN
# 13        NaN  clothing store    NaN             NaN              NaN
# 14        NaN        pharmacy    NaN             NaN              NaN
# 15        NaN      craft shop    NaN             NaN              NaN
# 16        NaN     barber shop    NaN             NaN              NaN
# 17        NaN   jewelry store    NaN             NaN              NaN
# 18        NaN          bakery    NaN             NaN              NaN
# 19        NaN  hardware store    NaN             NaN              NaN
# 20        NaN         florist    NaN             NaN              NaN
# 21        NaN       bike shop    NaN             NaN              NaN
# 22        NaN             gym    NaN             NaN              NaN
# 23        NaN            cafe    NaN             NaN              NaN
#
#     positionX  positionZ  correct direction (degrees)  \
# 0         NaN        NaN                          NaN
# 1         NaN        NaN                          NaN
# 2         NaN        NaN                          NaN
# 3         NaN        NaN                          NaN
# 4         NaN        NaN                          NaN
# 5         NaN        NaN                          NaN
# 6         NaN        NaN                          NaN
# 7         NaN        NaN                          NaN
# 8         NaN        NaN                          NaN
# 9         NaN        NaN                          NaN
# 10        NaN        NaN                          NaN
# 11        NaN        NaN                          NaN
# 12        NaN        NaN                          NaN
# 13        NaN        NaN                          NaN
# 14        NaN        NaN                          NaN
# 15        NaN        NaN                          NaN
# 16        NaN        NaN                          NaN
# 17        NaN        NaN                          NaN
# 18        NaN        NaN                          NaN
# 19        NaN        NaN                          NaN
# 20        NaN        NaN                          NaN
# 21        NaN        NaN                          NaN
# 22        NaN        NaN                          NaN
# 23        NaN        NaN                          NaN
#
#     pointed direction (degrees)  response subject itemno
# 0                           NaN       NaN  PILOT2    210
# 1                           NaN       NaN  PILOT2    124
# 2                           NaN       NaN  PILOT2    178
# 3                           NaN       NaN  PILOT2     58
# 4                           NaN       NaN  PILOT2    110
# 5                           NaN       NaN  PILOT2    131
# 6                           NaN       NaN  PILOT2     -1
# 7                           NaN       NaN  PILOT2     -1
# 8                           NaN       NaN  PILOT2    113
# 9                           NaN       NaN  PILOT2     28
# 10                          NaN       NaN  PILOT2     -1
# 11                          NaN       NaN  PILOT2    183
# 12                          NaN       NaN  PILOT2    204
# 13                          NaN       NaN  PILOT2     -1
# 14                          NaN       NaN  PILOT2     56
# 15                          NaN       NaN  PILOT2    175
# 16                          NaN       NaN  PILOT2     52
# 17                          NaN       NaN  PILOT2    161
# 18                          NaN       NaN  PILOT2    177
# 19                          NaN       NaN  PILOT2    189
# 20                          NaN       NaN  PILOT2    197
# 21                          NaN       NaN  PILOT2    217
# 22                          NaN       NaN  PILOT2    129
# 23                          NaN       NaN  PILOT2    212

# %%
# then, fill out the blanks
cued_recall_df["store"] = cued_recall_df["store"].astype(str)
cued_recall_df["store position"] = cued_recall_df["store position"].astype(str)

for i, row in cued_recall_df.iterrows():
    word_evs = df[(df.trial == row.trial) & (df.type == "WORD")]
    
    row_item = row["item"]
    recall_word = word_evs.query('item == @row_item')
    
    if len(recall_word) != 0:        
        serialpos = recall_word["serialpos"].values[0]
        store = recall_word["store"].values[0]
        store_position = recall_word["store position"].values[0]
        
        cued_recall_df.at[i, "serialpos"] = serialpos
        cued_recall_df.at[i, "store"] = store
        cued_recall_df.at[i, "store position"] = store_position
        
    else:
        cued_recall_df.at[i, "serialpos"] = -1
    
cued_recall_df
# Out:
#              type        mstime trial              item         cued_item  \
# 0   CUED_REC_WORD  1.649794e+12     0       sweet-n-low       sweet-n-low
# 1   CUED_REC_WORD  1.649794e+12     0             locks             locks
# 2   CUED_REC_WORD  1.649794e+12     0              rope              rope
# 3   CUED_REC_WORD  1.649794e+12     0      cotton_balls      cotton_balls
# 4   CUED_REC_WORD  1.649794e+12     0         head_band         head_band
# 5   CUED_REC_WORD  1.649794e+12     0              mice              mice
# 6   CUED_REC_WORD  1.649794e+12     0                <>       cough_syrup
# 7   CUED_REC_WORD  1.649794e+12     0                <>              yarn
# 8   CUED_REC_WORD  1.649794e+12     0         hula_hoop         hula_hoop
# 9   CUED_REC_WORD  1.649794e+12     0          bracelet          bracelet
# 10  CUED_REC_WORD  1.649794e+12     0                <>              bags
# 11  CUED_REC_WORD  1.649794e+12     0         saxophone         saxophone
# 12  CUED_REC_WORD  1.649794e+12     1    stuffed_animal    stuffed_animal
# 13  CUED_REC_WORD  1.649794e+12     1            tshirt             socks
# 14  CUED_REC_WORD  1.649794e+12     1  contact_solution  contact_solution
# 15  CUED_REC_WORD  1.649795e+12     1            ribbon            ribbon
# 16  CUED_REC_WORD  1.649795e+12     1              comb              comb
# 17  CUED_REC_WORD  1.649795e+12     1          platinum          platinum
# 18  CUED_REC_WORD  1.649795e+12     1              roll              roll
# 19  CUED_REC_WORD  1.649795e+12     1            screws            screws
# 20  CUED_REC_WORD  1.649795e+12     1              soil              soil
# 21  CUED_REC_WORD  1.649795e+12     1             tires            helmet
# 22  CUED_REC_WORD  1.649795e+12     1     medicine_ball     medicine_ball
# 23  CUED_REC_WORD  1.649795e+12     1             syrup             syrup
#
#     serialpos      cued_store           store          store position  \
# 0         2.0            cafe            cafe    (58.31, 4.05, 27.93)
# 1        10.0       bike shop       bike shop   (-31.82, 4.70, 55.71)
# 2        11.0             gym             gym  (-38.95, 0.00, -61.87)
# 3         5.0         dentist         dentist  (14.55, -0.04, -58.79)
# 4         4.0  clothing store  clothing store  (-60.00, 0.00, -11.50)
# 5         1.0       pet store       pet store   (32.20, 0.33, -60.90)
# 6        -1.0        pharmacy             nan                     nan
# 7        -1.0      craft shop             nan                     nan
# 8         9.0       toy store       toy store   (-3.07, 0.00, -58.51)
# 9         8.0   jewelry store   jewelry store   (62.34, 0.00, -33.51)
# 10       -1.0   grocery store             nan                     nan
# 11        3.0     music store     music store  (-29.57, 1.89, -37.24)
# 12        6.0       toy store       toy store   (-3.07, 0.00, -58.51)
# 13       -1.0  clothing store             nan                     nan
# 14        1.0        pharmacy        pharmacy  (-14.25, 0.00, -12.89)
# 15       11.0      craft shop      craft shop    (59.29, 4.65, -9.16)
# 16        3.0     barber shop     barber shop   (35.40, 0.00, -33.11)
# 17        5.0   jewelry store   jewelry store   (62.34, 0.00, -33.51)
# 18        4.0          bakery          bakery   (14.49, 2.27, -33.74)
# 19        7.0  hardware store  hardware store    (35.06, 0.00, 26.66)
# 20       10.0         florist         florist   (36.74, -1.91, 59.06)
# 21       -1.0       bike shop             nan                     nan
# 22        9.0             gym             gym  (-38.95, 0.00, -61.87)
# 23       12.0            cafe            cafe    (58.31, 4.05, 27.93)
#
#     player position  positionX  positionZ  correct direction (degrees)  \
# 0               NaN        NaN        NaN                          NaN
# 1               NaN        NaN        NaN                          NaN
# 2               NaN        NaN        NaN                          NaN
# 3               NaN        NaN        NaN                          NaN
# 4               NaN        NaN        NaN                          NaN
# 5               NaN        NaN        NaN                          NaN
# 6               NaN        NaN        NaN                          NaN
# 7               NaN        NaN        NaN                          NaN
# 8               NaN        NaN        NaN                          NaN
# 9               NaN        NaN        NaN                          NaN
# 10              NaN        NaN        NaN                          NaN
# 11              NaN        NaN        NaN                          NaN
# 12              NaN        NaN        NaN                          NaN
# 13              NaN        NaN        NaN                          NaN
# 14              NaN        NaN        NaN                          NaN
# 15              NaN        NaN        NaN                          NaN
# 16              NaN        NaN        NaN                          NaN
# 17              NaN        NaN        NaN                          NaN
# 18              NaN        NaN        NaN                          NaN
# 19              NaN        NaN        NaN                          NaN
# 20              NaN        NaN        NaN                          NaN
# 21              NaN        NaN        NaN                          NaN
# 22              NaN        NaN        NaN                          NaN
# 23              NaN        NaN        NaN                          NaN
#
#     pointed direction (degrees)  response subject itemno
# 0                           NaN       NaN  PILOT2    210
# 1                           NaN       NaN  PILOT2    124
# 2                           NaN       NaN  PILOT2    178
# 3                           NaN       NaN  PILOT2     58
# 4                           NaN       NaN  PILOT2    110
# 5                           NaN       NaN  PILOT2    131
# 6                           NaN       NaN  PILOT2     -1
# 7                           NaN       NaN  PILOT2     -1
# 8                           NaN       NaN  PILOT2    113
# 9                           NaN       NaN  PILOT2     28
# 10                          NaN       NaN  PILOT2     -1
# 11                          NaN       NaN  PILOT2    183
# 12                          NaN       NaN  PILOT2    204
# 13                          NaN       NaN  PILOT2     -1
# 14                          NaN       NaN  PILOT2     56
# 15                          NaN       NaN  PILOT2    175
# 16                          NaN       NaN  PILOT2     52
# 17                          NaN       NaN  PILOT2    161
# 18                          NaN       NaN  PILOT2    177
# 19                          NaN       NaN  PILOT2    189
# 20                          NaN       NaN  PILOT2    197
# 21                          NaN       NaN  PILOT2    217
# 22                          NaN       NaN  PILOT2    129
# 23                          NaN       NaN  PILOT2    212

# %% [markdown]
# # Final Free Recall Processing

# %%
FFR_store_df = pd.DataFrame(columns = df.columns)
FFR_store_start = df.query('type == "final store recall recording start"').mstime.values[0]

# let's load appropriate .ann files
data_dir = "/scratch/new_courier_pilot/{}/session_0/final store-0.ann".format(sub, count-1)
with open(data_dir, "r") as file:
    lines = file.readlines()
    for line in lines:
        if line[0] != "#":
            recall_info = line.strip("\n").split("\t")

            if len(recall_info) == 3:
                rectime = float(recall_info[0]) + FFR_store_start
                item = recall_info[2].lower()
                itemno = recall_info[1]
                
                FFR_store_df = FFR_store_df.append({"type":"FFR_STORE", "mstime":rectime, 
                                                    "item":item, "itemno":itemno, "subject":sub}, ignore_index=True)

FFR_store_df
# Out:
#          type        mstime  trial            item  cued_item  serialpos  \
# 0   FFR_STORE  1.649795e+12    NaN  hardware store        NaN        NaN
# 1   FFR_STORE  1.649795e+12    NaN   grocery store        NaN        NaN
# 2   FFR_STORE  1.649795e+12    NaN  clothing store        NaN        NaN
# 3   FFR_STORE  1.649795e+12    NaN            cafe        NaN        NaN
# 4   FFR_STORE  1.649795e+12    NaN          bakery        NaN        NaN
# 5   FFR_STORE  1.649795e+12    NaN         florist        NaN        NaN
# 6   FFR_STORE  1.649795e+12    NaN         dentist        NaN        NaN
# 7   FFR_STORE  1.649795e+12    NaN       pet store        NaN        NaN
# 8   FFR_STORE  1.649795e+12    NaN       toy store        NaN        NaN
# 9   FFR_STORE  1.649795e+12    NaN      craft shop        NaN        NaN
# 10  FFR_STORE  1.649795e+12    NaN             gym        NaN        NaN
# 11  FFR_STORE  1.649795e+12    NaN       pet store        NaN        NaN
# 12  FFR_STORE  1.649795e+12    NaN        pharmacy        NaN        NaN
# 13  FFR_STORE  1.649795e+12    NaN   jewelry store        NaN        NaN
# 14  FFR_STORE  1.649795e+12    NaN            cafe        NaN        NaN
#
#     cued_store  store  store position  player position  positionX  positionZ  \
# 0          NaN    NaN             NaN              NaN        NaN        NaN
# 1          NaN    NaN             NaN              NaN        NaN        NaN
# 2          NaN    NaN             NaN              NaN        NaN        NaN
# 3          NaN    NaN             NaN              NaN        NaN        NaN
# 4          NaN    NaN             NaN              NaN        NaN        NaN
# 5          NaN    NaN             NaN              NaN        NaN        NaN
# 6          NaN    NaN             NaN              NaN        NaN        NaN
# 7          NaN    NaN             NaN              NaN        NaN        NaN
# 8          NaN    NaN             NaN              NaN        NaN        NaN
# 9          NaN    NaN             NaN              NaN        NaN        NaN
# 10         NaN    NaN             NaN              NaN        NaN        NaN
# 11         NaN    NaN             NaN              NaN        NaN        NaN
# 12         NaN    NaN             NaN              NaN        NaN        NaN
# 13         NaN    NaN             NaN              NaN        NaN        NaN
# 14         NaN    NaN             NaN              NaN        NaN        NaN
#
#     correct direction (degrees)  pointed direction (degrees)  response  \
# 0                           NaN                          NaN       NaN
# 1                           NaN                          NaN       NaN
# 2                           NaN                          NaN       NaN
# 3                           NaN                          NaN       NaN
# 4                           NaN                          NaN       NaN
# 5                           NaN                          NaN       NaN
# 6                           NaN                          NaN       NaN
# 7                           NaN                          NaN       NaN
# 8                           NaN                          NaN       NaN
# 9                           NaN                          NaN       NaN
# 10                          NaN                          NaN       NaN
# 11                          NaN                          NaN       NaN
# 12                          NaN                          NaN       NaN
# 13                          NaN                          NaN       NaN
# 14                          NaN                          NaN       NaN
#
#    subject itemno
# 0   PILOT2     11
# 1   PILOT2      9
# 2   PILOT2      5
# 3   PILOT2      4
# 4   PILOT2      1
# 5   PILOT2      8
# 6   PILOT2      7
# 7   PILOT2     14
# 8   PILOT2     17
# 9   PILOT2      6
# 10  PILOT2     10
# 11  PILOT2     14
# 12  PILOT2     15
# 13  PILOT2     12
# 14  PILOT2      4

# %%
FFR_item_df = pd.DataFrame(columns = df.columns)
FFR_item_start = df.query('type == "final object recall recording start"').mstime.values[0]

# let's load appropriate .ann files
data_dir = "/scratch/new_courier_pilot/{}/session_0/final free-0.ann".format(sub, count-1)
with open(data_dir, "r") as file:
    lines = file.readlines()
    for line in lines:
        if line[0] != "#":
            recall_info = line.strip("\n").split("\t")

            if len(recall_info) == 3:
                rectime = float(recall_info[0]) + FFR_item_start
                item = recall_info[2].lower()
                itemno = recall_info[1]
                
                FFR_item_df = FFR_item_df.append({"type":"FFR_ITEM", "mstime":rectime, 
                                                  "item":item, "itemno":itemno, "subject":sub}, ignore_index=True)

FFR_item_df
# Out:
#         type        mstime  trial              item  cued_item  serialpos  \
# 0   FFR_ITEM  1.649795e+12    NaN            ribbon        NaN        NaN
# 1   FFR_ITEM  1.649795e+12    NaN              roll        NaN        NaN
# 2   FFR_ITEM  1.649795e+12    NaN         saxophone        NaN        NaN
# 3   FFR_ITEM  1.649795e+12    NaN       sweet-n-low        NaN        NaN
# 4   FFR_ITEM  1.649795e+12    NaN              soil        NaN        NaN
# 5   FFR_ITEM  1.649795e+12    NaN             locks        NaN        NaN
# 6   FFR_ITEM  1.649795e+12    NaN            screws        NaN        NaN
# 7   FFR_ITEM  1.649795e+12    NaN    stuffed_animal        NaN        NaN
# 8   FFR_ITEM  1.649795e+12    NaN         hula_hoop        NaN        NaN
# 9   FFR_ITEM  1.649795e+12    NaN  contact_solution        NaN        NaN
# 10  FFR_ITEM  1.649795e+12    NaN         head_band        NaN        NaN
# 11  FFR_ITEM  1.649795e+12    NaN          platinum        NaN        NaN
# 12  FFR_ITEM  1.649795e+12    NaN          bracelet        NaN        NaN
# 13  FFR_ITEM  1.649795e+12    NaN             syrup        NaN        NaN
# 14  FFR_ITEM  1.649795e+12    NaN     medicine_ball        NaN        NaN
# 15  FFR_ITEM  1.649795e+12    NaN              rope        NaN        NaN
# 16  FFR_ITEM  1.649795e+12    NaN              mice        NaN        NaN
# 17  FFR_ITEM  1.649795e+12    NaN           orchids        NaN        NaN
# 18  FFR_ITEM  1.649795e+12    NaN              comb        NaN        NaN
# 19  FFR_ITEM  1.649795e+12    NaN              cups        NaN        NaN
# 20  FFR_ITEM  1.649795e+12    NaN            tulips        NaN        NaN
# 21  FFR_ITEM  1.649795e+12    NaN      cotton_balls        NaN        NaN
# 22  FFR_ITEM  1.649795e+12    NaN          dumbells        NaN        NaN
# 23  FFR_ITEM  1.649795e+12    NaN          doughnut        NaN        NaN
# 24  FFR_ITEM  1.649795e+12    NaN         saxophone        NaN        NaN
#
#     cued_store  store  store position  player position  positionX  positionZ  \
# 0          NaN    NaN             NaN              NaN        NaN        NaN
# 1          NaN    NaN             NaN              NaN        NaN        NaN
# 2          NaN    NaN             NaN              NaN        NaN        NaN
# 3          NaN    NaN             NaN              NaN        NaN        NaN
# 4          NaN    NaN             NaN              NaN        NaN        NaN
# 5          NaN    NaN             NaN              NaN        NaN        NaN
# 6          NaN    NaN             NaN              NaN        NaN        NaN
# 7          NaN    NaN             NaN              NaN        NaN        NaN
# 8          NaN    NaN             NaN              NaN        NaN        NaN
# 9          NaN    NaN             NaN              NaN        NaN        NaN
# 10         NaN    NaN             NaN              NaN        NaN        NaN
# 11         NaN    NaN             NaN              NaN        NaN        NaN
# 12         NaN    NaN             NaN              NaN        NaN        NaN
# 13         NaN    NaN             NaN              NaN        NaN        NaN
# 14         NaN    NaN             NaN              NaN        NaN        NaN
# 15         NaN    NaN             NaN              NaN        NaN        NaN
# 16         NaN    NaN             NaN              NaN        NaN        NaN
# 17         NaN    NaN             NaN              NaN        NaN        NaN
# 18         NaN    NaN             NaN              NaN        NaN        NaN
# 19         NaN    NaN             NaN              NaN        NaN        NaN
# 20         NaN    NaN             NaN              NaN        NaN        NaN
# 21         NaN    NaN             NaN              NaN        NaN        NaN
# 22         NaN    NaN             NaN              NaN        NaN        NaN
# 23         NaN    NaN             NaN              NaN        NaN        NaN
# 24         NaN    NaN             NaN              NaN        NaN        NaN
#
#     correct direction (degrees)  pointed direction (degrees)  response  \
# 0                           NaN                          NaN       NaN
# 1                           NaN                          NaN       NaN
# 2                           NaN                          NaN       NaN
# 3                           NaN                          NaN       NaN
# 4                           NaN                          NaN       NaN
# 5                           NaN                          NaN       NaN
# 6                           NaN                          NaN       NaN
# 7                           NaN                          NaN       NaN
# 8                           NaN                          NaN       NaN
# 9                           NaN                          NaN       NaN
# 10                          NaN                          NaN       NaN
# 11                          NaN                          NaN       NaN
# 12                          NaN                          NaN       NaN
# 13                          NaN                          NaN       NaN
# 14                          NaN                          NaN       NaN
# 15                          NaN                          NaN       NaN
# 16                          NaN                          NaN       NaN
# 17                          NaN                          NaN       NaN
# 18                          NaN                          NaN       NaN
# 19                          NaN                          NaN       NaN
# 20                          NaN                          NaN       NaN
# 21                          NaN                          NaN       NaN
# 22                          NaN                          NaN       NaN
# 23                          NaN                          NaN       NaN
# 24                          NaN                          NaN       NaN
#
#    subject itemno
# 0   PILOT2    175
# 1   PILOT2    177
# 2   PILOT2    183
# 3   PILOT2    210
# 4   PILOT2    197
# 5   PILOT2    124
# 6   PILOT2    189
# 7   PILOT2    204
# 8   PILOT2    113
# 9   PILOT2     56
# 10  PILOT2    110
# 11  PILOT2    161
# 12  PILOT2     28
# 13  PILOT2    212
# 14  PILOT2    129
# 15  PILOT2    178
# 16  PILOT2    131
# 17  PILOT2    148
# 18  PILOT2     52
# 19  PILOT2     62
# 20  PILOT2     -1
# 21  PILOT2     58
# 22  PILOT2     74
# 23  PILOT2     71
# 24  PILOT2    183

# %%
# then, fill out the blanks
FFR_item_df["store"] = FFR_item_df["store"].astype(str)
FFR_item_df["store position"] = FFR_item_df["store position"].astype(str)

for i, row in FFR_item_df.iterrows():
    word_evs = df.query('type == "WORD"')
    
    row_item = row["item"]
    recall_word = word_evs.query('item == @row_item')
    
    if len(recall_word) != 0:        
        serialpos = recall_word["serialpos"].values[0]
        store = recall_word["store"].values[0]
        store_position = recall_word["store position"].values[0]
        
        FFR_item_df.at[i, "serialpos"] = serialpos
        FFR_item_df.at[i, "store"] = store
        FFR_item_df.at[i, "store position"] = store_position
        
    else:
        FFR_item_df.at[i, "serialpos"] = -1
    
FFR_item_df
# Out:
#         type        mstime  trial              item  cued_item  serialpos  \
# 0   FFR_ITEM  1.649795e+12    NaN            ribbon        NaN       11.0
# 1   FFR_ITEM  1.649795e+12    NaN              roll        NaN        4.0
# 2   FFR_ITEM  1.649795e+12    NaN         saxophone        NaN        3.0
# 3   FFR_ITEM  1.649795e+12    NaN       sweet-n-low        NaN        2.0
# 4   FFR_ITEM  1.649795e+12    NaN              soil        NaN       10.0
# 5   FFR_ITEM  1.649795e+12    NaN             locks        NaN       10.0
# 6   FFR_ITEM  1.649795e+12    NaN            screws        NaN        7.0
# 7   FFR_ITEM  1.649795e+12    NaN    stuffed_animal        NaN        6.0
# 8   FFR_ITEM  1.649795e+12    NaN         hula_hoop        NaN        9.0
# 9   FFR_ITEM  1.649795e+12    NaN  contact_solution        NaN        1.0
# 10  FFR_ITEM  1.649795e+12    NaN         head_band        NaN        4.0
# 11  FFR_ITEM  1.649795e+12    NaN          platinum        NaN        5.0
# 12  FFR_ITEM  1.649795e+12    NaN          bracelet        NaN        8.0
# 13  FFR_ITEM  1.649795e+12    NaN             syrup        NaN       12.0
# 14  FFR_ITEM  1.649795e+12    NaN     medicine_ball        NaN        9.0
# 15  FFR_ITEM  1.649795e+12    NaN              rope        NaN       11.0
# 16  FFR_ITEM  1.649795e+12    NaN              mice        NaN        1.0
# 17  FFR_ITEM  1.649795e+12    NaN           orchids        NaN       -1.0
# 18  FFR_ITEM  1.649795e+12    NaN              comb        NaN        3.0
# 19  FFR_ITEM  1.649795e+12    NaN              cups        NaN       -1.0
# 20  FFR_ITEM  1.649795e+12    NaN            tulips        NaN       -1.0
# 21  FFR_ITEM  1.649795e+12    NaN      cotton_balls        NaN        5.0
# 22  FFR_ITEM  1.649795e+12    NaN          dumbells        NaN       -1.0
# 23  FFR_ITEM  1.649795e+12    NaN          doughnut        NaN       -1.0
# 24  FFR_ITEM  1.649795e+12    NaN         saxophone        NaN        3.0
#
#     cued_store           store          store position  player position  \
# 0          NaN      craft shop    (59.29, 4.65, -9.16)              NaN
# 1          NaN          bakery   (14.49, 2.27, -33.74)              NaN
# 2          NaN     music store  (-29.57, 1.89, -37.24)              NaN
# 3          NaN            cafe    (58.31, 4.05, 27.93)              NaN
# 4          NaN         florist   (36.74, -1.91, 59.06)              NaN
# 5          NaN       bike shop   (-31.82, 4.70, 55.71)              NaN
# 6          NaN  hardware store    (35.06, 0.00, 26.66)              NaN
# 7          NaN       toy store   (-3.07, 0.00, -58.51)              NaN
# 8          NaN       toy store   (-3.07, 0.00, -58.51)              NaN
# 9          NaN        pharmacy  (-14.25, 0.00, -12.89)              NaN
# 10         NaN  clothing store  (-60.00, 0.00, -11.50)              NaN
# 11         NaN   jewelry store   (62.34, 0.00, -33.51)              NaN
# 12         NaN   jewelry store   (62.34, 0.00, -33.51)              NaN
# 13         NaN            cafe    (58.31, 4.05, 27.93)              NaN
# 14         NaN             gym  (-38.95, 0.00, -61.87)              NaN
# 15         NaN             gym  (-38.95, 0.00, -61.87)              NaN
# 16         NaN       pet store   (32.20, 0.33, -60.90)              NaN
# 17         NaN             nan                     nan              NaN
# 18         NaN     barber shop   (35.40, 0.00, -33.11)              NaN
# 19         NaN             nan                     nan              NaN
# 20         NaN             nan                     nan              NaN
# 21         NaN         dentist  (14.55, -0.04, -58.79)              NaN
# 22         NaN             nan                     nan              NaN
# 23         NaN             nan                     nan              NaN
# 24         NaN     music store  (-29.57, 1.89, -37.24)              NaN
#
#     positionX  positionZ  correct direction (degrees)  \
# 0         NaN        NaN                          NaN
# 1         NaN        NaN                          NaN
# 2         NaN        NaN                          NaN
# 3         NaN        NaN                          NaN
# 4         NaN        NaN                          NaN
# 5         NaN        NaN                          NaN
# 6         NaN        NaN                          NaN
# 7         NaN        NaN                          NaN
# 8         NaN        NaN                          NaN
# 9         NaN        NaN                          NaN
# 10        NaN        NaN                          NaN
# 11        NaN        NaN                          NaN
# 12        NaN        NaN                          NaN
# 13        NaN        NaN                          NaN
# 14        NaN        NaN                          NaN
# 15        NaN        NaN                          NaN
# 16        NaN        NaN                          NaN
# 17        NaN        NaN                          NaN
# 18        NaN        NaN                          NaN
# 19        NaN        NaN                          NaN
# 20        NaN        NaN                          NaN
# 21        NaN        NaN                          NaN
# 22        NaN        NaN                          NaN
# 23        NaN        NaN                          NaN
# 24        NaN        NaN                          NaN
#
#     pointed direction (degrees)  response subject itemno
# 0                           NaN       NaN  PILOT2    175
# 1                           NaN       NaN  PILOT2    177
# 2                           NaN       NaN  PILOT2    183
# 3                           NaN       NaN  PILOT2    210
# 4                           NaN       NaN  PILOT2    197
# 5                           NaN       NaN  PILOT2    124
# 6                           NaN       NaN  PILOT2    189
# 7                           NaN       NaN  PILOT2    204
# 8                           NaN       NaN  PILOT2    113
# 9                           NaN       NaN  PILOT2     56
# 10                          NaN       NaN  PILOT2    110
# 11                          NaN       NaN  PILOT2    161
# 12                          NaN       NaN  PILOT2     28
# 13                          NaN       NaN  PILOT2    212
# 14                          NaN       NaN  PILOT2    129
# 15                          NaN       NaN  PILOT2    178
# 16                          NaN       NaN  PILOT2    131
# 17                          NaN       NaN  PILOT2    148
# 18                          NaN       NaN  PILOT2     52
# 19                          NaN       NaN  PILOT2     62
# 20                          NaN       NaN  PILOT2     -1
# 21                          NaN       NaN  PILOT2     58
# 22                          NaN       NaN  PILOT2     74
# 23                          NaN       NaN  PILOT2     71
# 24                          NaN       NaN  PILOT2    183

# %% [markdown]
# # Add them up

# %%
# now put it in right place
tmp = df.copy()
tmp = tmp.append(recall_df)
tmp = tmp.append(cued_recall_df)
tmp = tmp.append(FFR_store_df)
tmp = tmp.append(FFR_item_df)
tmp = tmp.sort_values('mstime').reset_index(drop=True)

# %% [markdown]
# # add "recalled" column

# %%
with open('/home1/leochang/ELEMEM_PILOT/all_items.txt', "r") as f:
    wordpool = [w.strip() for w in f.readlines()]
with open('/data/behavioral/mturk/dictionary.txt', 'r') as f:
    dictionary = [w.strip().replace("_", " ") for w in f.readlines()]

# %%
tmp = add_recalled(tmp)
tmp.query('type == "WORD" | type == "REC_WORD"')

# %% [markdown]
# # Add "session" column

# %%
tmp["session"] = 0
tmp
# Out:
#                    type        mstime trial item cued_item  serialpos  \
# 0              versions  1.649792e+12   NaN  NaN       NaN        NaN
# 1      experimentConfig  1.649792e+12   NaN  NaN       NaN        NaN
# 2          systemConfig  1.649792e+12   NaN  NaN       NaN        NaN
# 3       PlayerTransform  1.649792e+12   NaN  NaN       NaN        NaN
# 4        store mappings  1.649792e+12   NaN  NaN       NaN        NaN
# ...                 ...           ...   ...  ...       ...        ...
# 18535   PlayerTransform  1.649795e+12   NaN  NaN       NaN        NaN
# 18536   PlayerTransform  1.649795e+12   NaN  NaN       NaN        NaN
# 18537   PlayerTransform  1.649795e+12   NaN  NaN       NaN        NaN
# 18538   PlayerTransform  1.649795e+12   NaN  NaN       NaN        NaN
# 18539   PlayerTransform  1.649795e+12   NaN  NaN       NaN        NaN
#
#       cued_store store store position player position     positionX  \
# 0            NaN   NaN            NaN             NaN           NaN
# 1            NaN   NaN            NaN             NaN           NaN
# 2            NaN   NaN            NaN             NaN           NaN
# 3            NaN   NaN            NaN             NaN -9.536743e-07
# 4            NaN   NaN            NaN             NaN           NaN
# ...          ...   ...            ...             ...           ...
# 18535        NaN   NaN            NaN             NaN  3.327605e+01
# 18536        NaN   NaN            NaN             NaN  3.327605e+01
# 18537        NaN   NaN            NaN             NaN  3.327605e+01
# 18538        NaN   NaN            NaN             NaN  3.327605e+01
# 18539        NaN   NaN            NaN             NaN  3.327605e+01
#
#           positionZ  correct direction (degrees)  pointed direction (degrees)  \
# 0               NaN                          NaN                          NaN
# 1               NaN                          NaN                          NaN
# 2               NaN                          NaN                          NaN
# 3     -1.364242e-12                          NaN                          NaN
# 4               NaN                          NaN                          NaN
# ...             ...                          ...                          ...
# 18535 -4.904773e+01                          NaN                          NaN
# 18536 -4.904773e+01                          NaN                          NaN
# 18537 -4.904773e+01                          NaN                          NaN
# 18538 -4.904773e+01                          NaN                          NaN
# 18539 -4.904773e+01                          NaN                          NaN
#
#       response subject itemno  recalled  session
# 0          NaN  PILOT2    NaN       NaN        0
# 1          NaN  PILOT2    NaN       NaN        0
# 2          NaN  PILOT2    NaN       NaN        0
# 3          NaN  PILOT2    NaN       NaN        0
# 4          NaN  PILOT2    NaN       NaN        0
# ...        ...     ...    ...       ...      ...
# 18535      NaN  PILOT2    NaN       NaN        0
# 18536      NaN  PILOT2    NaN       NaN        0
# 18537      NaN  PILOT2    NaN       NaN        0
# 18538      NaN  PILOT2    NaN       NaN        0
# 18539      NaN  PILOT2    NaN       NaN        0
#
# [18540 rows x 19 columns]

# %% [markdown]
# # Add "itemno" values to WORD events

# %%
def get_item_id(item, wordpool):
    if item not in wordpool:
        return -1
    return wordpool.index(item)+1

def add_itemno(events, wordpool):
    events.loc[(events["type"] == 'WORD'), "itemno"] = \
    events.loc[(events["type"] == 'WORD'), "item"].apply(lambda x: get_item_id(x, wordpool))

    return events
                                                    
tmp = add_itemno(tmp, wordpool)
tmp.query('type == "WORD" | type == "REC_WORD"')
# Out:
#            type        mstime trial              item cued_item  serialpos  \
# 7565       WORD  1.649793e+12   0.0              mice       NaN        1.0
# 7888       WORD  1.649793e+12   0.0       sweet-n-low       NaN        2.0
# 8176       WORD  1.649793e+12   0.0         saxophone       NaN        3.0
# 8545       WORD  1.649794e+12   0.0         head_band       NaN        4.0
# 8724       WORD  1.649794e+12   0.0      cotton_balls       NaN        5.0
# 9085       WORD  1.649794e+12   0.0              yarn       NaN        6.0
# 9251       WORD  1.649794e+12   0.0       cough_syrup       NaN        7.0
# 9413       WORD  1.649794e+12   0.0          bracelet       NaN        8.0
# 9541       WORD  1.649794e+12   0.0         hula_hoop       NaN        9.0
# 9838       WORD  1.649794e+12   0.0             locks       NaN       10.0
# 10047      WORD  1.649794e+12   0.0              rope       NaN       11.0
# 10237      WORD  1.649794e+12   0.0              bags       NaN       12.0
# 10471  REC_WORD  1.649794e+12     0              eggs       NaN       -1.0
# 10481  REC_WORD  1.649794e+12     0         hula_hoop       NaN        9.0
# 10488  REC_WORD  1.649794e+12     0              rope       NaN       11.0
# 10499  REC_WORD  1.649794e+12     0             locks       NaN       10.0
# 10510  REC_WORD  1.649794e+12     0         saxophone       NaN        3.0
# 10522  REC_WORD  1.649794e+12     0      cotton_balls       NaN        5.0
# 10532  REC_WORD  1.649794e+12     0       sweet-n-low       NaN        2.0
# 10548  REC_WORD  1.649794e+12     0         head_band       NaN        4.0
# 10606  REC_WORD  1.649794e+12     0           muffins       NaN       -1.0
# 10661  REC_WORD  1.649794e+12     0          bracelet       NaN        8.0
# 12358      WORD  1.649794e+12   1.0  contact_solution       NaN        1.0
# 12679      WORD  1.649794e+12   1.0             socks       NaN        2.0
# 12874      WORD  1.649794e+12   1.0              comb       NaN        3.0
# 13264      WORD  1.649794e+12   1.0              roll       NaN        4.0
# 13433      WORD  1.649794e+12   1.0          platinum       NaN        5.0
# 13659      WORD  1.649794e+12   1.0    stuffed_animal       NaN        6.0
# 13902      WORD  1.649794e+12   1.0            screws       NaN        7.0
# 14048      WORD  1.649794e+12   1.0            helmet       NaN        8.0
# 14268      WORD  1.649794e+12   1.0     medicine_ball       NaN        9.0
# 14515      WORD  1.649794e+12   1.0              soil       NaN       10.0
# 14656      WORD  1.649794e+12   1.0            ribbon       NaN       11.0
# 14770      WORD  1.649794e+12   1.0             syrup       NaN       12.0
# 15186  REC_WORD  1.649794e+12     1             syrup       NaN       12.0
# 15198  REC_WORD  1.649794e+12     1            ribbon       NaN       11.0
# 15206  REC_WORD  1.649794e+12     1              comb       NaN        3.0
# 15219  REC_WORD  1.649794e+12     1              roll       NaN        4.0
# 15246  REC_WORD  1.649794e+12     1  contact_solution       NaN        1.0
# 15273  REC_WORD  1.649794e+12     1    stuffed_animal       NaN        6.0
# 15296  REC_WORD  1.649794e+12     1          platinum       NaN        5.0
# 15318  REC_WORD  1.649794e+12     1     medicine_ball       NaN        9.0
# 15348  REC_WORD  1.649794e+12     1            screws       NaN        7.0
# 15375  REC_WORD  1.649794e+12     1              soil       NaN       10.0
#
#       cued_store           store          store position  \
# 7565         NaN       pet store   (32.20, 0.33, -60.90)
# 7888         NaN            cafe    (58.31, 4.05, 27.93)
# 8176         NaN     music store  (-29.57, 1.89, -37.24)
# 8545         NaN  clothing store  (-60.00, 0.00, -11.50)
# 8724         NaN         dentist  (14.55, -0.04, -58.79)
# 9085         NaN      craft shop    (59.29, 4.65, -9.16)
# 9251         NaN        pharmacy  (-14.25, 0.00, -12.89)
# 9413         NaN   jewelry store   (62.34, 0.00, -33.51)
# 9541         NaN       toy store   (-3.07, 0.00, -58.51)
# 9838         NaN       bike shop   (-31.82, 4.70, 55.71)
# 10047        NaN             gym  (-38.95, 0.00, -61.87)
# 10237        NaN   grocery store    (26.49, 0.58, 16.95)
# 10471        NaN             nan                     nan
# 10481        NaN       toy store   (-3.07, 0.00, -58.51)
# 10488        NaN             gym  (-38.95, 0.00, -61.87)
# 10499        NaN       bike shop   (-31.82, 4.70, 55.71)
# 10510        NaN     music store  (-29.57, 1.89, -37.24)
# 10522        NaN         dentist  (14.55, -0.04, -58.79)
# 10532        NaN            cafe    (58.31, 4.05, 27.93)
# 10548        NaN  clothing store  (-60.00, 0.00, -11.50)
# 10606        NaN             nan                     nan
# 10661        NaN   jewelry store   (62.34, 0.00, -33.51)
# 12358        NaN        pharmacy  (-14.25, 0.00, -12.89)
# 12679        NaN  clothing store  (-60.00, 0.00, -11.50)
# 12874        NaN     barber shop   (35.40, 0.00, -33.11)
# 13264        NaN          bakery   (14.49, 2.27, -33.74)
# 13433        NaN   jewelry store   (62.34, 0.00, -33.51)
# 13659        NaN       toy store   (-3.07, 0.00, -58.51)
# 13902        NaN  hardware store    (35.06, 0.00, 26.66)
# 14048        NaN       bike shop   (-31.82, 4.70, 55.71)
# 14268        NaN             gym  (-38.95, 0.00, -61.87)
# 14515        NaN         florist   (36.74, -1.91, 59.06)
# 14656        NaN      craft shop    (59.29, 4.65, -9.16)
# 14770        NaN            cafe    (58.31, 4.05, 27.93)
# 15186        NaN            cafe    (58.31, 4.05, 27.93)
# 15198        NaN      craft shop    (59.29, 4.65, -9.16)
# 15206        NaN     barber shop   (35.40, 0.00, -33.11)
# 15219        NaN          bakery   (14.49, 2.27, -33.74)
# 15246        NaN        pharmacy  (-14.25, 0.00, -12.89)
# 15273        NaN       toy store   (-3.07, 0.00, -58.51)
# 15296        NaN   jewelry store   (62.34, 0.00, -33.51)
# 15318        NaN             gym  (-38.95, 0.00, -61.87)
# 15348        NaN  hardware store    (35.06, 0.00, 26.66)
# 15375        NaN         florist   (36.74, -1.91, 59.06)
#
#               player position  positionX  positionZ  \
# 7565    (31.26, 0.00, -49.05)        NaN        NaN
# 7888     (49.46, 0.00, 28.18)        NaN        NaN
# 8176   (-28.74, 0.00, -46.53)        NaN        NaN
# 8545   (-48.87, 0.00, -10.78)        NaN        NaN
# 8724     (9.57, 0.00, -48.95)        NaN        NaN
# 9085     (49.50, 0.00, -8.45)        NaN        NaN
# 9251     (-0.87, 0.00, -9.18)        NaN        NaN
# 9413    (50.37, 0.00, -32.72)        NaN        NaN
# 9541    (-6.36, 0.00, -49.47)        NaN        NaN
# 9838    (-29.23, 0.00, 49.50)        NaN        NaN
# 10047  (-36.52, 0.00, -49.25)        NaN        NaN
# 10237     (26.00, 0.00, 1.57)        NaN        NaN
# 10471                     NaN        NaN        NaN
# 10481                     NaN        NaN        NaN
# 10488                     NaN        NaN        NaN
# 10499                     NaN        NaN        NaN
# 10510                     NaN        NaN        NaN
# 10522                     NaN        NaN        NaN
# 10532                     NaN        NaN        NaN
# 10548                     NaN        NaN        NaN
# 10606                     NaN        NaN        NaN
# 10661                     NaN        NaN        NaN
# 12358    (-0.77, 0.00, -9.30)        NaN        NaN
# 12679  (-48.70, 0.00, -10.88)        NaN        NaN
# 12874   (46.89, 0.00, -29.80)        NaN        NaN
# 13264    (1.48, 0.00, -34.06)        NaN        NaN
# 13433   (50.26, 0.00, -32.66)        NaN        NaN
# 13659   (-6.94, 0.00, -48.56)        NaN        NaN
# 13902    (46.40, 0.00, 31.62)        NaN        NaN
# 14048   (-29.35, 0.00, 49.46)        NaN        NaN
# 14268  (-38.66, 0.00, -49.07)        NaN        NaN
# 14515    (37.52, 0.00, 48.92)        NaN        NaN
# 14656    (49.63, 0.00, -8.41)        NaN        NaN
# 14770    (49.37, 0.00, 26.03)        NaN        NaN
# 15186                     NaN        NaN        NaN
# 15198                     NaN        NaN        NaN
# 15206                     NaN        NaN        NaN
# 15219                     NaN        NaN        NaN
# 15246                     NaN        NaN        NaN
# 15273                     NaN        NaN        NaN
# 15296                     NaN        NaN        NaN
# 15318                     NaN        NaN        NaN
# 15348                     NaN        NaN        NaN
# 15375                     NaN        NaN        NaN
#
#        correct direction (degrees)  pointed direction (degrees) response  \
# 7565                           NaN                          NaN      NaN
# 7888                           NaN                          NaN      NaN
# 8176                           NaN                          NaN      NaN
# 8545                           NaN                          NaN      NaN
# 8724                           NaN                          NaN      NaN
# 9085                           NaN                          NaN      NaN
# 9251                           NaN                          NaN      NaN
# 9413                           NaN                          NaN      NaN
# 9541                           NaN                          NaN      NaN
# 9838                           NaN                          NaN      NaN
# 10047                          NaN                          NaN      NaN
# 10237                          NaN                          NaN      NaN
# 10471                          NaN                          NaN      NaN
# 10481                          NaN                          NaN      NaN
# 10488                          NaN                          NaN      NaN
# 10499                          NaN                          NaN      NaN
# 10510                          NaN                          NaN      NaN
# 10522                          NaN                          NaN      NaN
# 10532                          NaN                          NaN      NaN
# 10548                          NaN                          NaN      NaN
# 10606                          NaN                          NaN      NaN
# 10661                          NaN                          NaN      NaN
# 12358                          NaN                          NaN      NaN
# 12679                          NaN                          NaN      NaN
# 12874                          NaN                          NaN      NaN
# 13264                          NaN                          NaN      NaN
# 13433                          NaN                          NaN      NaN
# 13659                          NaN                          NaN      NaN
# 13902                          NaN                          NaN      NaN
# 14048                          NaN                          NaN      NaN
# 14268                          NaN                          NaN      NaN
# 14515                          NaN                          NaN      NaN
# 14656                          NaN                          NaN      NaN
# 14770                          NaN                          NaN      NaN
# 15186                          NaN                          NaN      NaN
# 15198                          NaN                          NaN      NaN
# 15206                          NaN                          NaN      NaN
# 15219                          NaN                          NaN      NaN
# 15246                          NaN                          NaN      NaN
# 15273                          NaN                          NaN      NaN
# 15296                          NaN                          NaN      NaN
# 15318                          NaN                          NaN      NaN
# 15348                          NaN                          NaN      NaN
# 15375                          NaN                          NaN      NaN
#
#       subject itemno  recalled  session
# 7565   PILOT2    131       0.0        0
# 7888   PILOT2    210       1.0        0
# 8176   PILOT2    183       1.0        0
# 8545   PILOT2    110       1.0        0
# 8724   PILOT2     58       1.0        0
# 9085   PILOT2    237       0.0        0
# 9251   PILOT2     59       0.0        0
# 9413   PILOT2     28       1.0        0
# 9541   PILOT2    113       1.0        0
# 9838   PILOT2    124       1.0        0
# 10047  PILOT2    178       1.0        0
# 10237  PILOT2     13       0.0        0
# 10471  PILOT2     77       NaN        0
# 10481  PILOT2    113       NaN        0
# 10488  PILOT2    178       NaN        0
# 10499  PILOT2    124       NaN        0
# 10510  PILOT2    183       NaN        0
# 10522  PILOT2     58       NaN        0
# 10532  PILOT2    210       NaN        0
# 10548  PILOT2    110       NaN        0
# 10606  PILOT2    136       NaN        0
# 10661  PILOT2     28       NaN        0
# 12358  PILOT2     56       1.0        0
# 12679  PILOT2    196       0.0        0
# 12874  PILOT2     52       1.0        0
# 13264  PILOT2    177       1.0        0
# 13433  PILOT2    161       1.0        0
# 13659  PILOT2    204       1.0        0
# 13902  PILOT2    189       1.0        0
# 14048  PILOT2    111       0.0        0
# 14268  PILOT2    129       1.0        0
# 14515  PILOT2    197       1.0        0
# 14656  PILOT2    175       1.0        0
# 14770  PILOT2    212       1.0        0
# 15186  PILOT2    212       NaN        0
# 15198  PILOT2    175       NaN        0
# 15206  PILOT2     52       NaN        0
# 15219  PILOT2    177       NaN        0
# 15246  PILOT2     56       NaN        0
# 15273  PILOT2    204       NaN        0
# 15296  PILOT2    161       NaN        0
# 15318  PILOT2    129       NaN        0
# 15348  PILOT2    189       NaN        0
# 15375  PILOT2    197       NaN        0

# %%
tmp.query('type == "WORD"')
# Out:
#        type        mstime trial              item cued_item  serialpos  \
# 7565   WORD  1.649793e+12   0.0              mice       NaN        1.0
# 7888   WORD  1.649793e+12   0.0       sweet-n-low       NaN        2.0
# 8176   WORD  1.649793e+12   0.0         saxophone       NaN        3.0
# 8545   WORD  1.649794e+12   0.0         head_band       NaN        4.0
# 8724   WORD  1.649794e+12   0.0      cotton_balls       NaN        5.0
# 9085   WORD  1.649794e+12   0.0              yarn       NaN        6.0
# 9251   WORD  1.649794e+12   0.0       cough_syrup       NaN        7.0
# 9413   WORD  1.649794e+12   0.0          bracelet       NaN        8.0
# 9541   WORD  1.649794e+12   0.0         hula_hoop       NaN        9.0
# 9838   WORD  1.649794e+12   0.0             locks       NaN       10.0
# 10047  WORD  1.649794e+12   0.0              rope       NaN       11.0
# 10237  WORD  1.649794e+12   0.0              bags       NaN       12.0
# 12358  WORD  1.649794e+12   1.0  contact_solution       NaN        1.0
# 12679  WORD  1.649794e+12   1.0             socks       NaN        2.0
# 12874  WORD  1.649794e+12   1.0              comb       NaN        3.0
# 13264  WORD  1.649794e+12   1.0              roll       NaN        4.0
# 13433  WORD  1.649794e+12   1.0          platinum       NaN        5.0
# 13659  WORD  1.649794e+12   1.0    stuffed_animal       NaN        6.0
# 13902  WORD  1.649794e+12   1.0            screws       NaN        7.0
# 14048  WORD  1.649794e+12   1.0            helmet       NaN        8.0
# 14268  WORD  1.649794e+12   1.0     medicine_ball       NaN        9.0
# 14515  WORD  1.649794e+12   1.0              soil       NaN       10.0
# 14656  WORD  1.649794e+12   1.0            ribbon       NaN       11.0
# 14770  WORD  1.649794e+12   1.0             syrup       NaN       12.0
#
#       cued_store           store          store position  \
# 7565         NaN       pet store   (32.20, 0.33, -60.90)
# 7888         NaN            cafe    (58.31, 4.05, 27.93)
# 8176         NaN     music store  (-29.57, 1.89, -37.24)
# 8545         NaN  clothing store  (-60.00, 0.00, -11.50)
# 8724         NaN         dentist  (14.55, -0.04, -58.79)
# 9085         NaN      craft shop    (59.29, 4.65, -9.16)
# 9251         NaN        pharmacy  (-14.25, 0.00, -12.89)
# 9413         NaN   jewelry store   (62.34, 0.00, -33.51)
# 9541         NaN       toy store   (-3.07, 0.00, -58.51)
# 9838         NaN       bike shop   (-31.82, 4.70, 55.71)
# 10047        NaN             gym  (-38.95, 0.00, -61.87)
# 10237        NaN   grocery store    (26.49, 0.58, 16.95)
# 12358        NaN        pharmacy  (-14.25, 0.00, -12.89)
# 12679        NaN  clothing store  (-60.00, 0.00, -11.50)
# 12874        NaN     barber shop   (35.40, 0.00, -33.11)
# 13264        NaN          bakery   (14.49, 2.27, -33.74)
# 13433        NaN   jewelry store   (62.34, 0.00, -33.51)
# 13659        NaN       toy store   (-3.07, 0.00, -58.51)
# 13902        NaN  hardware store    (35.06, 0.00, 26.66)
# 14048        NaN       bike shop   (-31.82, 4.70, 55.71)
# 14268        NaN             gym  (-38.95, 0.00, -61.87)
# 14515        NaN         florist   (36.74, -1.91, 59.06)
# 14656        NaN      craft shop    (59.29, 4.65, -9.16)
# 14770        NaN            cafe    (58.31, 4.05, 27.93)
#
#               player position  positionX  positionZ  \
# 7565    (31.26, 0.00, -49.05)        NaN        NaN
# 7888     (49.46, 0.00, 28.18)        NaN        NaN
# 8176   (-28.74, 0.00, -46.53)        NaN        NaN
# 8545   (-48.87, 0.00, -10.78)        NaN        NaN
# 8724     (9.57, 0.00, -48.95)        NaN        NaN
# 9085     (49.50, 0.00, -8.45)        NaN        NaN
# 9251     (-0.87, 0.00, -9.18)        NaN        NaN
# 9413    (50.37, 0.00, -32.72)        NaN        NaN
# 9541    (-6.36, 0.00, -49.47)        NaN        NaN
# 9838    (-29.23, 0.00, 49.50)        NaN        NaN
# 10047  (-36.52, 0.00, -49.25)        NaN        NaN
# 10237     (26.00, 0.00, 1.57)        NaN        NaN
# 12358    (-0.77, 0.00, -9.30)        NaN        NaN
# 12679  (-48.70, 0.00, -10.88)        NaN        NaN
# 12874   (46.89, 0.00, -29.80)        NaN        NaN
# 13264    (1.48, 0.00, -34.06)        NaN        NaN
# 13433   (50.26, 0.00, -32.66)        NaN        NaN
# 13659   (-6.94, 0.00, -48.56)        NaN        NaN
# 13902    (46.40, 0.00, 31.62)        NaN        NaN
# 14048   (-29.35, 0.00, 49.46)        NaN        NaN
# 14268  (-38.66, 0.00, -49.07)        NaN        NaN
# 14515    (37.52, 0.00, 48.92)        NaN        NaN
# 14656    (49.63, 0.00, -8.41)        NaN        NaN
# 14770    (49.37, 0.00, 26.03)        NaN        NaN
#
#        correct direction (degrees)  pointed direction (degrees) response  \
# 7565                           NaN                          NaN      NaN
# 7888                           NaN                          NaN      NaN
# 8176                           NaN                          NaN      NaN
# 8545                           NaN                          NaN      NaN
# 8724                           NaN                          NaN      NaN
# 9085                           NaN                          NaN      NaN
# 9251                           NaN                          NaN      NaN
# 9413                           NaN                          NaN      NaN
# 9541                           NaN                          NaN      NaN
# 9838                           NaN                          NaN      NaN
# 10047                          NaN                          NaN      NaN
# 10237                          NaN                          NaN      NaN
# 12358                          NaN                          NaN      NaN
# 12679                          NaN                          NaN      NaN
# 12874                          NaN                          NaN      NaN
# 13264                          NaN                          NaN      NaN
# 13433                          NaN                          NaN      NaN
# 13659                          NaN                          NaN      NaN
# 13902                          NaN                          NaN      NaN
# 14048                          NaN                          NaN      NaN
# 14268                          NaN                          NaN      NaN
# 14515                          NaN                          NaN      NaN
# 14656                          NaN                          NaN      NaN
# 14770                          NaN                          NaN      NaN
#
#       subject itemno  recalled  session
# 7565   PILOT2    131       0.0        0
# 7888   PILOT2    210       1.0        0
# 8176   PILOT2    183       1.0        0
# 8545   PILOT2    110       1.0        0
# 8724   PILOT2     58       1.0        0
# 9085   PILOT2    237       0.0        0
# 9251   PILOT2     59       0.0        0
# 9413   PILOT2     28       1.0        0
# 9541   PILOT2    113       1.0        0
# 9838   PILOT2    124       1.0        0
# 10047  PILOT2    178       1.0        0
# 10237  PILOT2     13       0.0        0
# 12358  PILOT2     56       1.0        0
# 12679  PILOT2    196       0.0        0
# 12874  PILOT2     52       1.0        0
# 13264  PILOT2    177       1.0        0
# 13433  PILOT2    161       1.0        0
# 13659  PILOT2    204       1.0        0
# 13902  PILOT2    189       1.0        0
# 14048  PILOT2    111       0.0        0
# 14268  PILOT2    129       1.0        0
# 14515  PILOT2    197       1.0        0
# 14656  PILOT2    175       1.0        0
# 14770  PILOT2    212       1.0        0

# %% [markdown]
# # Add "intrusion" column

# %%
def add_intrusion(events):
    '''
    uses REC_WORD and WORD events to determine if a recalled word is a PLI/XLI
    '''
    events = events.sort_values("mstime")

    def check_list(row):

        presentation = events[(events["type"] == 'WORD') \
                              & (events["itemno"] == row["itemno"]) \
                              & (events["trial"] <= row["trial"])]

        if len(presentation.index) == 0:
            return -1
        else:
            # also captures repeated presentations
            list_delta = row["trial"] - presentation.iloc[-1]["trial"]
            # list_delta = list_delta.values[0] # Series are annoying

            return -1 if list_delta < 0 else list_delta

    events.loc[events["type"] == 'REC_WORD', "intrusion"] = events[events["type"] == 'REC_WORD'].apply(check_list, axis=1)

    return events

tmp[["trial", "serialpos", "recalled", "itemno", "intrusion"]] = tmp[["trial", "serialpos", "recalled", "itemno", "intrusion"]].fillna(-999)
tmp = tmp.astype({"trial":int, "serialpos":int, "recalled":int, "itemno":int, "intrusion":int})
tmp = add_intrusion(tmp)
tmp.query('type == "REC_WORD"')
# Out:
#            type        mstime  trial              item cued_item  serialpos  \
# 10471  REC_WORD  1.649794e+12      0              eggs       NaN         -1
# 10481  REC_WORD  1.649794e+12      0         hula_hoop       NaN          9
# 10488  REC_WORD  1.649794e+12      0              rope       NaN         11
# 10499  REC_WORD  1.649794e+12      0             locks       NaN         10
# 10510  REC_WORD  1.649794e+12      0         saxophone       NaN          3
# 10522  REC_WORD  1.649794e+12      0      cotton_balls       NaN          5
# 10532  REC_WORD  1.649794e+12      0       sweet-n-low       NaN          2
# 10548  REC_WORD  1.649794e+12      0         head_band       NaN          4
# 10606  REC_WORD  1.649794e+12      0           muffins       NaN         -1
# 10661  REC_WORD  1.649794e+12      0          bracelet       NaN          8
# 15186  REC_WORD  1.649794e+12      1             syrup       NaN         12
# 15198  REC_WORD  1.649794e+12      1            ribbon       NaN         11
# 15206  REC_WORD  1.649794e+12      1              comb       NaN          3
# 15219  REC_WORD  1.649794e+12      1              roll       NaN          4
# 15246  REC_WORD  1.649794e+12      1  contact_solution       NaN          1
# 15273  REC_WORD  1.649794e+12      1    stuffed_animal       NaN          6
# 15296  REC_WORD  1.649794e+12      1          platinum       NaN          5
# 15318  REC_WORD  1.649794e+12      1     medicine_ball       NaN          9
# 15348  REC_WORD  1.649794e+12      1            screws       NaN          7
# 15375  REC_WORD  1.649794e+12      1              soil       NaN         10
#
#       cued_store           store          store position player position  \
# 10471        NaN             nan                     nan             NaN
# 10481        NaN       toy store   (-3.07, 0.00, -58.51)             NaN
# 10488        NaN             gym  (-38.95, 0.00, -61.87)             NaN
# 10499        NaN       bike shop   (-31.82, 4.70, 55.71)             NaN
# 10510        NaN     music store  (-29.57, 1.89, -37.24)             NaN
# 10522        NaN         dentist  (14.55, -0.04, -58.79)             NaN
# 10532        NaN            cafe    (58.31, 4.05, 27.93)             NaN
# 10548        NaN  clothing store  (-60.00, 0.00, -11.50)             NaN
# 10606        NaN             nan                     nan             NaN
# 10661        NaN   jewelry store   (62.34, 0.00, -33.51)             NaN
# 15186        NaN            cafe    (58.31, 4.05, 27.93)             NaN
# 15198        NaN      craft shop    (59.29, 4.65, -9.16)             NaN
# 15206        NaN     barber shop   (35.40, 0.00, -33.11)             NaN
# 15219        NaN          bakery   (14.49, 2.27, -33.74)             NaN
# 15246        NaN        pharmacy  (-14.25, 0.00, -12.89)             NaN
# 15273        NaN       toy store   (-3.07, 0.00, -58.51)             NaN
# 15296        NaN   jewelry store   (62.34, 0.00, -33.51)             NaN
# 15318        NaN             gym  (-38.95, 0.00, -61.87)             NaN
# 15348        NaN  hardware store    (35.06, 0.00, 26.66)             NaN
# 15375        NaN         florist   (36.74, -1.91, 59.06)             NaN
#
#        positionX  positionZ  correct direction (degrees)  \
# 10471        NaN        NaN                          NaN
# 10481        NaN        NaN                          NaN
# 10488        NaN        NaN                          NaN
# 10499        NaN        NaN                          NaN
# 10510        NaN        NaN                          NaN
# 10522        NaN        NaN                          NaN
# 10532        NaN        NaN                          NaN
# 10548        NaN        NaN                          NaN
# 10606        NaN        NaN                          NaN
# 10661        NaN        NaN                          NaN
# 15186        NaN        NaN                          NaN
# 15198        NaN        NaN                          NaN
# 15206        NaN        NaN                          NaN
# 15219        NaN        NaN                          NaN
# 15246        NaN        NaN                          NaN
# 15273        NaN        NaN                          NaN
# 15296        NaN        NaN                          NaN
# 15318        NaN        NaN                          NaN
# 15348        NaN        NaN                          NaN
# 15375        NaN        NaN                          NaN
#
#        pointed direction (degrees) response subject  itemno  recalled  \
# 10471                          NaN      NaN  PILOT2      77      -999
# 10481                          NaN      NaN  PILOT2     113      -999
# 10488                          NaN      NaN  PILOT2     178      -999
# 10499                          NaN      NaN  PILOT2     124      -999
# 10510                          NaN      NaN  PILOT2     183      -999
# 10522                          NaN      NaN  PILOT2      58      -999
# 10532                          NaN      NaN  PILOT2     210      -999
# 10548                          NaN      NaN  PILOT2     110      -999
# 10606                          NaN      NaN  PILOT2     136      -999
# 10661                          NaN      NaN  PILOT2      28      -999
# 15186                          NaN      NaN  PILOT2     212      -999
# 15198                          NaN      NaN  PILOT2     175      -999
# 15206                          NaN      NaN  PILOT2      52      -999
# 15219                          NaN      NaN  PILOT2     177      -999
# 15246                          NaN      NaN  PILOT2      56      -999
# 15273                          NaN      NaN  PILOT2     204      -999
# 15296                          NaN      NaN  PILOT2     161      -999
# 15318                          NaN      NaN  PILOT2     129      -999
# 15348                          NaN      NaN  PILOT2     189      -999
# 15375                          NaN      NaN  PILOT2     197      -999
#
#        session  intrusion
# 10471        0         -1
# 10481        0          0
# 10488        0          0
# 10499        0          0
# 10510        0          0
# 10522        0          0
# 10532        0          0
# 10548        0          0
# 10606        0         -1
# 10661        0          0
# 15186        0          0
# 15198        0          0
# 15206        0          0
# 15219        0          0
# 15246        0          0
# 15273        0          0
# 15296        0          0
# 15318        0          0
# 15348        0          0
# 15375        0          0

# %%
tmp.to_csv("{}.csv".format(sub))

# %%
# FREE RECALL
rec_evs = tmp.query('type == "REC_WORD" | type == "REC_STOP"')
rec_evs_index = rec_evs.index

for i in range(len(rec_evs)-1):

    curr_row = rec_evs.iloc[i]
    if curr_row.type != "REC_WORD":
        continue
    next_row = rec_evs.iloc[i+1]

    curr_time = curr_row.mstime
    next_time = next_row.mstime

    EFR_candidates = tmp.query('(type == "keypress" | type == "key press/release") & mstime > @curr_time & mstime < @next_time')
    display(EFR_candidates)
    if len(EFR_candidates.query('type == "keypress"')) > 0:
        responses = EFR_candidates["key code"].unique()
        responses = responses[~np.isnan(responses)]
        print(responses)
        
        response_time = EFR_candidates.query('type == "keypress"').mstime.values[0]
        print(response_time)
    
        tmp.at[rec_evs_index[i], "keypress"] = True
        tmp.at[rec_evs_index[i], "keypress_code"] = responses
        tmp.at[rec_evs_index[i], "keypress_mstime"] = response_time
        
        break
# Out:
# Empty DataFrame
# Columns: [type, mstime, trial, item, cued_item, serialpos, cued_store, store, store position, player position, positionX, positionZ, correct direction (degrees), pointed direction (degrees), response, key code, subject, session, recalled, intrusion, itemno, keypress, keypress_mstime]
# Index: []
# Empty DataFrame
# Columns: [type, mstime, trial, item, cued_item, serialpos, cued_store, store, store position, player position, positionX, positionZ, correct direction (degrees), pointed direction (degrees), response, key code, subject, session, recalled, intrusion, itemno, keypress, keypress_mstime]
# Index: []
# Empty DataFrame
# Columns: [type, mstime, trial, item, cued_item, serialpos, cued_store, store, store position, player position, positionX, positionZ, correct direction (degrees), pointed direction (degrees), response, key code, subject, session, recalled, intrusion, itemno, keypress, keypress_mstime]
# Index: []
# Empty DataFrame
# Columns: [type, mstime, trial, item, cued_item, serialpos, cued_store, store, store position, player position, positionX, positionZ, correct direction (degrees), pointed direction (degrees), response, key code, subject, session, recalled, intrusion, itemno, keypress, keypress_mstime]
# Index: []
#                     type        mstime  trial item cued_item  serialpos  \
# 10359           keypress  1.649776e+12   -999  NaN       NaN       -999
# 10360  key press/release  1.649776e+12   -999  NaN       NaN       -999
# 10363  key press/release  1.649776e+12   -999  NaN       NaN       -999
#
#       cued_store store store position player position  positionX  positionZ  \
# 10359        NaN   NaN            NaN             NaN        NaN        NaN
# 10360        NaN   NaN            NaN             NaN        NaN        NaN
# 10363        NaN   NaN            NaN             NaN        NaN        NaN
#
#        correct direction (degrees)  pointed direction (degrees)  \
# 10359                          NaN                          NaN
# 10360                          NaN                          NaN
# 10363                          NaN                          NaN
#
#             response  key code subject session  recalled  intrusion  itemno  \
# 10359  reject button       NaN  PILOT1       0      -999       -999    -999
# 10360            NaN      98.0  PILOT1       0      -999       -999    -999
# 10363            NaN      98.0  PILOT1       0      -999       -999    -999
#
#       keypress  keypress_mstime
# 10359      NaN              NaN
# 10360      NaN              NaN
# 10363      NaN              NaN
# [98.]
# 1649776105647.93

# %%
tmp.query('type == "REC_WORD"')
# Out:
#            type        mstime  trial              item cued_item  serialpos  \
# 10286  REC_WORD  1.649776e+12      0   chocolate_chips       NaN         12
# 10300  REC_WORD  1.649776e+12      0           hamster       NaN         10
# 10313  REC_WORD  1.649776e+12      0            helmet       NaN          9
# 10325  REC_WORD  1.649776e+12      0             socks       NaN          6
# 10342  REC_WORD  1.649776e+12      0            straws       NaN          7
# 10483  REC_WORD  1.649776e+12      0             socks       NaN          6
# 10512  REC_WORD  1.649776e+12      0            helmet       NaN          9
# 14382  REC_WORD  1.649777e+12      1             ferns       NaN         12
# 14394  REC_WORD  1.649777e+12      1           cookies       NaN         11
# 14406  REC_WORD  1.649777e+12      1          computer       NaN          1
# 14421  REC_WORD  1.649777e+12      1         jump_rope       NaN          3
# 14436  REC_WORD  1.649777e+12      1  contact_solution       NaN       -999
# 14554  REC_WORD  1.649777e+12      1            lotion       NaN          2
#
#       cued_store           store          store position player position  \
# 10286        NaN          bakery   (62.34, 0.00, -33.51)             NaN
# 10300        NaN       pet store  (-38.95, 0.00, -61.87)             NaN
# 10313        NaN       bike shop    (35.06, 0.00, 26.66)             NaN
# 10325        NaN  clothing store   (32.20, 0.33, -60.90)             NaN
# 10342        NaN            cafe    (26.49, 0.58, 16.95)             NaN
# 10483        NaN  clothing store   (32.20, 0.33, -60.90)             NaN
# 10512        NaN       bike shop    (35.06, 0.00, 26.66)             NaN
# 14382        NaN         florist    (58.31, 4.05, 27.93)             NaN
# 14394        NaN          bakery   (62.34, 0.00, -33.51)             NaN
# 14406        NaN         dentist  (-14.25, 0.00, -12.89)             NaN
# 14421        NaN             gym   (-3.07, 0.00, -58.51)             NaN
# 14436        NaN             nan                     nan             NaN
# 14554        NaN        pharmacy  (-60.00, 0.00, -11.50)             NaN
#
#        positionX  positionZ  correct direction (degrees)  \
# 10286        NaN        NaN                          NaN
# 10300        NaN        NaN                          NaN
# 10313        NaN        NaN                          NaN
# 10325        NaN        NaN                          NaN
# 10342        NaN        NaN                          NaN
# 10483        NaN        NaN                          NaN
# 10512        NaN        NaN                          NaN
# 14382        NaN        NaN                          NaN
# 14394        NaN        NaN                          NaN
# 14406        NaN        NaN                          NaN
# 14421        NaN        NaN                          NaN
# 14436        NaN        NaN                          NaN
# 14554        NaN        NaN                          NaN
#
#        pointed direction (degrees) response  key code subject session  \
# 10286                          NaN      NaN       NaN  PILOT1       0
# 10300                          NaN      NaN       NaN  PILOT1       0
# 10313                          NaN      NaN       NaN  PILOT1       0
# 10325                          NaN      NaN       NaN  PILOT1       0
# 10342                          NaN      NaN       NaN  PILOT1       0
# 10483                          NaN      NaN       NaN  PILOT1       0
# 10512                          NaN      NaN       NaN  PILOT1       0
# 14382                          NaN      NaN       NaN  PILOT1       0
# 14394                          NaN      NaN       NaN  PILOT1       0
# 14406                          NaN      NaN       NaN  PILOT1       0
# 14421                          NaN      NaN       NaN  PILOT1       0
# 14436                          NaN      NaN       NaN  PILOT1       0
# 14554                          NaN      NaN       NaN  PILOT1       0
#
#        recalled  intrusion  itemno keypress  keypress_mstime  keypress_code
# 10286      -999         -1      47      NaN              NaN            NaN
# 10300      -999         -1     105      NaN              NaN            NaN
# 10313      -999         -1     111      NaN              NaN            NaN
# 10325      -999         -1     196      NaN              NaN            NaN
# 10342      -999         -1     203     True     1.649776e+12           98.0
# 10483      -999         -1     196     True              NaN            NaN
# 10512      -999         -1     111     True              NaN            NaN
# 14382      -999         -1      82      NaN              NaN            NaN
# 14394      -999         -1      57      NaN              NaN            NaN
# 14406      -999         -1      53      NaN              NaN            NaN
# 14421      -999         -1     116      NaN              NaN            NaN
# 14436      -999         -1      56     True              NaN            NaN
# 14554      -999         -1     126      NaN              NaN            NaN
